# %% [markdown]
# See https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf for more information about 1d convolutions and time series classification

# %%
# Check if tensorflow finds the runtime GPU
import tensorflow as tf


print(tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('GPU device not found')
else:
  print('Found GPU at: {}'.format(device_name))
# Out:
# 2.8.2
# Found GPU at: /device:GPU:0

# %%
# Clone the repository
# Out:
# Cloning into 'fc_crash-detection'...
# remote: Enumerating objects: 18779, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 18779 (delta 13), reused 9 (delta 4), pack-reused 18749
# Receiving objects: 100% (18779/18779), 2.00 GiB | 18.26 MiB/s, done.
# Resolving deltas: 100% (835/835), done.
# Checking out files: 100% (16051/16051), done.

# %%
# Mount Google Drive
from google.colab import drive


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set params
dataset_path = '/content/fc_crash-detection/crash-dataset-csv/microbox'
test_dataset_path = '/content/drive/MyDrive/data_aug_dataset/microbox' # Where to save test set
results_path = '/content/drive/MyDrive'
model_name = 'microbox_fft_xyz_300_data_aug_1' # In results_path
mode = "fft" # time or fft
test_split = 0.2
validation_split = 0.1
max_epoch = 1000
min_delta = 0
patience = 60

# %%
# Define some functions
from tqdm.notebook import tqdm
from scipy.fft import fft
import numpy as np
import pandas as pd
import glob
import os


def preprocess_microbox(entry):
  loaded_entry = entry.values[1:3000,4:7]
  #numpy slicing [start:stop:step]
  loaded_entry_subsamp = loaded_entry[::10].copy()

  return loaded_entry_subsamp


def get_dataset(path):

  entry_list = []

  files_list = glob.glob(os.path.join(path, "*.csv"))
  # Load every csv inside path as a numpy matrix, preprocess and create a list
  for filename in tqdm(files_list):
    ds_entry = pd.read_csv(filename, index_col=None, header=0)
    ds_entry_processed = preprocess_microbox(ds_entry)
    entry_list.append(ds_entry_processed)

  # Convert list to a numpy array. Cast to float32 to avoid errors on fit
  ds_array = np.asarray(entry_list).astype('float32')

  return ds_array

# %%
# Define the rotations matrices for data augmentation
import numpy as np
import math as m

 
def Rx(theta):
  return np.matrix([[ 1, 0           , 0           ],
                   [ 0, m.cos(theta),-m.sin(theta)],
                   [ 0, m.sin(theta), m.cos(theta)]])
 
def Ry(theta):
  return np.matrix([[ m.cos(theta), 0, m.sin(theta)],
                   [ 0           , 1, 0           ],
                   [-m.sin(theta), 0, m.cos(theta)]])
 
def Rz(theta):
  return np.matrix([[ m.cos(theta), -m.sin(theta), 0 ],
                   [ m.sin(theta), m.cos(theta) , 0 ],
                   [ 0           , 0            , 1 ]])

steps = 181 # Equal steps between -max angle to +max angle (including angle 0)
angle = m.pi/4 # +/-max angle
rotations = 10 # Number of rotations to use for training set data augmentation

R = []
for i in range(-int((steps - 1)/2), int((steps - 1)/2) + 1):
  a = i*angle*(1/((steps - 1)/2))
  for j in range(-int((steps - 1)/2), int((steps - 1)/2) + 1):
    b = j*angle*(1/((steps - 1)/2))
    for z in range(-int((steps - 1)/2), int((steps - 1)/2) + 1):
      c = z*angle*(1/((steps - 1)/2))
      if not (a == 0 and b == 0 and c == 0):
        R_ = Rz(a) * Ry(b) * Rx(c)
        R.append(R_)
print("Number of combinations: " + str(len(R) + 1))
# Out:
# Number of combinations: 5929741

# %%
# Load data
ds_false_init = get_dataset(dataset_path + '/false')
ds_true_init = get_dataset(dataset_path + '/true')

print("\nFalse-class data:")
print(ds_false_init.shape)

print("\nTrue-class data:")
print(ds_false_init.shape)
# Out:
#   0%|          | 0/962 [00:00<?, ?it/s]
#   0%|          | 0/962 [00:00<?, ?it/s]
# False-class data:
# (962, 300, 3)
#
# True-class data:
# (962, 300, 3)

# %%
# Train test split
import numpy as np
import random
from sklearn.model_selection import train_test_split


ds_false_train, X_test_false = train_test_split(ds_false_init, test_size = test_split)
ds_true_train, X_test_true = train_test_split(ds_true_init, test_size = test_split)

# Series rotation for ds_false test
ds_aug = X_test_false[0,:,:].copy()
ds_false_aug = []
for j in range(0, X_test_false.shape[0]):
  n = random.randint(0,len(R))
  if n == len(R): # Null rotation
    ds_aug = X_test_false[j,:,:]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
  else: # Apply rotation
    for i in range(0, X_test_false.shape[1]):
      v1 = np.array([[X_test_false[j,i,0]],[X_test_false[j,i,1]],[X_test_false[j,i,2]]])
      v2 = R[n] * v1
      ds_aug[i, 0] = v2[0,0]
      ds_aug[i, 1] = v2[1,0]
      ds_aug[i, 2] = v2[2,0]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)

  if mode == "fft":
    ds_false_aug.append(ds_entry_fft)
  if mode == "time":
    ds_false_aug.append(ds_aug)
# Convert list to a numpy array
ds_false = np.asarray(ds_false_aug).astype('float32')

# Series rotation for ds_true test
ds_aug = X_test_true[0,:,:].copy()
ds_true_aug = []
for j in range(0, X_test_true.shape[0]):
  n = random.randint(0,len(R))
  if n == len(R): # Null rotation
    ds_aug = X_test_true[j,:,:]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
  else: # Apply rotation
    for i in range(0, X_test_true.shape[1]):
      v1 = np.array([[X_test_true[j,i,0]],[X_test_true[j,i,1]],[X_test_true[j,i,2]]])
      v2 = R[n] * v1
      ds_aug[i, 0] = v2[0,0]
      ds_aug[i, 1] = v2[1,0]
      ds_aug[i, 2] = v2[2,0]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)

  if mode == "fft":
    ds_true_aug.append(ds_entry_fft)
  if mode == "time":
    ds_true_aug.append(ds_aug)
# Convert list to a numpy array
ds_true = np.asarray(ds_true_aug).astype('float32')

# Build all-false labels (one hot encoding, two classes, two columns)
ds_false_labels = np.zeros((len(ds_false),2))
# Set all first column to one
ds_false_labels[:,0] = 1
print("False-class test data:")
print(ds_false.shape)
print(ds_false_labels.shape)

# Build all-true labels (one hot encoding, two classes, two columns)
ds_true_labels = np.zeros((len(ds_true),2))
# Set all second column to one
ds_true_labels[:,1] = 1
print("\nTrue-class test data:")
print(ds_true.shape)
print(ds_true_labels.shape)

X_test = np.concatenate((ds_false, ds_true), axis = 0)
y_test = np.concatenate((ds_false_labels, ds_true_labels), axis = 0)
print("\nAll test data:")
print(X_test.shape)
print(y_test.shape)

# Train validation split
ds_false_no_aug, X_val_false = train_test_split(ds_false_train, test_size = validation_split)
ds_true_no_aug, X_val_true = train_test_split(ds_true_train, test_size = validation_split)

# Series rotation for ds_false validation
ds_aug = X_val_false[0,:,:].copy()
ds_false_aug = []
for j in range(0, X_val_false.shape[0]):
  n = random.randint(0,len(R))
  if n == len(R): # Null rotation
    ds_aug = X_val_false[j,:,:]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
  else: # Apply rotation
    for i in range(0, X_val_false.shape[1]):
      v1 = np.array([[X_val_false[j,i,0]],[X_val_false[j,i,1]],[X_val_false[j,i,2]]])
      v2 = R[n] * v1
      ds_aug[i, 0] = v2[0,0]
      ds_aug[i, 1] = v2[1,0]
      ds_aug[i, 2] = v2[2,0]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)

  if mode == "fft":
    ds_false_aug.append(ds_entry_fft)
  if mode == "time":
    ds_false_aug.append(ds_aug)
# Convert list to a numpy array
ds_false = np.asarray(ds_false_aug).astype('float32')

# Series rotation for ds_true validation
ds_aug = X_val_true[0,:,:].copy()
ds_true_aug = []
for j in range(0, X_val_true.shape[0]):
  n = random.randint(0,len(R))
  if n == len(R): # Null rotation
    ds_aug = X_val_true[j,:,:]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
  else: # Apply rotation
    for i in range(0, X_val_true.shape[1]):
      v1 = np.array([[X_val_true[j,i,0]],[X_val_true[j,i,1]],[X_val_true[j,i,2]]])
      v2 = R[n] * v1
      ds_aug[i, 0] = v2[0,0]
      ds_aug[i, 1] = v2[1,0]
      ds_aug[i, 2] = v2[2,0]

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_x = fft(ds_aug[:,0])
      fft_y = fft(ds_aug[:,1])
      fft_z = fft(ds_aug[:,2])

      d_x = np.absolute(fft_x)
      d_y = np.absolute(fft_y)
      d_z = np.absolute(fft_z)

      ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
      
  if mode == "fft":
    ds_true_aug.append(ds_entry_fft)
  if mode == "time":
    ds_true_aug.append(ds_aug)
# Convert list to a numpy array
ds_true = np.asarray(ds_true_aug).astype('float32')

# Build all-false labels (one hot encoding, two classes, two columns)
ds_false_labels = np.zeros((len(ds_false),2))
# Set all first column to one
ds_false_labels[:,0] = 1
print("\nFalse-class validation data:")
print(ds_false.shape)
print(ds_false_labels.shape)

# Build all-true labels (one hot encoding, two classes, two columns)
ds_true_labels = np.zeros((len(ds_true),2))
# Set all second column to one
ds_true_labels[:,1] = 1
print("\nTrue-class validation data:")
print(ds_true.shape)
print(ds_true_labels.shape)

# Concatenate false-class/true-class data and labels
X_val = np.concatenate((ds_false, ds_true), axis = 0)
y_val = np.concatenate((ds_false_labels, ds_true_labels), axis = 0)
print("\nAll validation data:")
print(X_val.shape)
print(y_val.shape)

# Data augmentation for ds_false train
ds_aug = ds_false_no_aug[0,:,:].copy()
ds_false_aug = []
for j in range(0, ds_false_no_aug.shape[0]):
  randomlist = []
  while len(randomlist) < rotations: # Fill with random rotations
    n = random.randint(0,len(R))
    if n not in randomlist:
      randomlist.append(n)
  for k in range (0, len(randomlist)):
    if randomlist[k] == len(R): # Null rotation
      ds_aug = ds_false_no_aug[j,:,:]

      if mode == "fft": # If mode fft, apply fast Fourier transform

        fft_x = fft(ds_aug[:,0])
        fft_y = fft(ds_aug[:,1])
        fft_z = fft(ds_aug[:,2])

        d_x = np.absolute(fft_x)
        d_y = np.absolute(fft_y)
        d_z = np.absolute(fft_z)

        ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
    else: # Apply rotations
      for i in range(0, ds_false_no_aug.shape[1]):
        v1 = np.array([[ds_false_no_aug[j,i,0]],[ds_false_no_aug[j,i,1]],[ds_false_no_aug[j,i,2]]])
        v2 = R[randomlist[k]] * v1
        ds_aug[i, 0] = v2[0,0]
        ds_aug[i, 1] = v2[1,0]
        ds_aug[i, 2] = v2[2,0]

      if mode == "fft": # If mode fft, apply fast Fourier transform

        fft_x = fft(ds_aug[:,0])
        fft_y = fft(ds_aug[:,1])
        fft_z = fft(ds_aug[:,2])

        d_x = np.absolute(fft_x)
        d_y = np.absolute(fft_y)
        d_z = np.absolute(fft_z)

        ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)

    if mode == "fft":
      ds_false_aug.append(ds_entry_fft)
    if mode == "time":
      ds_false_aug.append(ds_aug)
# Convert list to a numpy array. Cast to float32 to avoid errors on fit
ds_false = np.asarray(ds_false_aug).astype('float32')

# Data augmentation for ds_true train
ds_aug = ds_true_no_aug[0,:,:].copy()
ds_true_aug = []
for j in range(0, ds_true_no_aug.shape[0]):     
  randomlist = []
  while len(randomlist) < rotations: # Fill with random rotations
    n = random.randint(0,len(R))
    if n not in randomlist:
      randomlist.append(n)
  for k in range (0, len(randomlist)):
    if randomlist[k] == len(R): # Null rotation
      ds_aug = ds_true_no_aug[j,:,:]

      if mode == "fft": # If mode fft, apply fast Fourier transform

        fft_x = fft(ds_aug[:,0])
        fft_y = fft(ds_aug[:,1])
        fft_z = fft(ds_aug[:,2])

        d_x = np.absolute(fft_x)
        d_y = np.absolute(fft_y)
        d_z = np.absolute(fft_z)

        ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)
    else: # Apply rotations
      for i in range(0, ds_true_no_aug.shape[1]):
        v1 = np.array([[ds_true_no_aug[j,i,0]],[ds_true_no_aug[j,i,1]],[ds_true_no_aug[j,i,2]]])
        v2 = R[randomlist[k]] * v1
        ds_aug[i, 0] = v2[0,0]
        ds_aug[i, 1] = v2[1,0]
        ds_aug[i, 2] = v2[2,0]

      if mode == "fft": # If mode fft, apply fast Fourier transform

        fft_x = fft(ds_aug[:,0])
        fft_y = fft(ds_aug[:,1])
        fft_z = fft(ds_aug[:,2])

        d_x = np.absolute(fft_x)
        d_y = np.absolute(fft_y)
        d_z = np.absolute(fft_z)

        ds_entry_fft = np.stack([d_x, d_y, d_z], axis=1)

    if mode == "fft":
      ds_true_aug.append(ds_entry_fft)
    if mode == "time":
      ds_true_aug.append(ds_aug)
# Convert list to a numpy array. Cast to float32 to avoid errors on fit
ds_true = np.asarray(ds_true_aug).astype('float32')

# Build all-false labels (one hot encoding, two classes, two columns)
ds_false_labels = np.zeros((len(ds_false),2))
# Set all first column to one
ds_false_labels[:,0] = 1
print("\nFalse-class train data:")
print(ds_false.shape)
print(ds_false_labels.shape)

# Build all-true labels (one hot encoding, two classes, two columns)
ds_true_labels = np.zeros((len(ds_true),2))
# Set all second column to one
ds_true_labels[:,1] = 1
print("\nTrue-class train data:")
print(ds_true.shape)
print(ds_true_labels.shape)

# Concatenate false-class/true-class data and labels
X_train = np.concatenate((ds_false, ds_true), axis = 0)
y_train = np.concatenate((ds_false_labels, ds_true_labels), axis = 0)
print("\nAll train data:")
print(X_train.shape)
print(y_train.shape)
del ds_false_train, ds_true_train, ds_false_no_aug, ds_true_no_aug, ds_false, ds_true, ds_false_labels, ds_true_labels, ds_aug, ds_false_aug, ds_true_aug
# Out:
# False-class test data:
# (193, 300, 3)
# (193, 2)
#
# True-class test data:
# (193, 300, 3)
# (193, 2)
#
# All test data:
# (386, 300, 3)
# (386, 2)
#
# False-class validation data:
# (77, 300, 3)
# (77, 2)
#
# True-class validation data:
# (77, 300, 3)
# (77, 2)
#
# All validation data:
# (154, 300, 3)
# (154, 2)
#
# False-class train data:
# (6920, 300, 3)
# (6920, 2)
#
# True-class train data:
# (6920, 300, 3)
# (6920, 2)
#
# All train data:
# (13840, 300, 3)
# (13840, 2)

# %%
# Plot a single sample of data
from matplotlib import pyplot as plt
import numpy as np
import random


sample = random.randint(0, X_train.shape[0])
x = np.arange(0,len(X_train[sample]))

fig = plt.figure(figsize=(16,8))
plt.plot(x, X_train[sample,:,0], "blue", label="x")
plt.plot(x, X_train[sample,:,1], "red", label="y")
plt.plot(x, X_train[sample,:,2], "green", label="z")
plt.legend(loc="upper right")
plt.show()

# %%
# Create the model
import tensorflow as tf
from tensorflow.keras.layers import Dense,Dropout,Conv1D,MaxPooling1D,GlobalMaxPooling1D


# Model definition
model = tf.keras.models.Sequential()

input_shape=(X_train.shape[1],X_train.shape[2])
model.add(Conv1D(100, 10, activation='relu', input_shape=input_shape))
#model.add(Conv1D(100, 10, activation='relu'))
model.add(MaxPooling1D(20))
model.add(Dropout(0.2))
model.add(Conv1D(50, 2, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Dropout(0.1))
model.add(Conv1D(25, 2, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dropout(0.1))
model.add(Dense(y_train.shape[1], activation='softmax'))

# Define optimizer, learning rate, and compile model
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#               loss=tf.keras.losses.BinaryCrossentropy(),
#               metrics=['accuracy'])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.005),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', 'AUC'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 291, 100)          3100
#
#  max_pooling1d (MaxPooling1D  (None, 14, 100)          0
#  )
#
#  dropout (Dropout)           (None, 14, 100)           0
#
#  conv1d_1 (Conv1D)           (None, 13, 50)            10050
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 50)            0
#  1D)
#
#  dropout_1 (Dropout)         (None, 2, 50)             0
#
#  conv1d_2 (Conv1D)           (None, 1, 25)             2525
#
#  global_max_pooling1d (Globa  (None, 25)               0
#  lMaxPooling1D)
#
#  dropout_2 (Dropout)         (None, 25)                0
#
#  dense (Dense)               (None, 2)                 52
#
# =================================================================
# Total params: 15,727
# Trainable params: 15,727
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train
from matplotlib import pyplot as plt
import tensorflow as tf


checkpoint = tf.keras.callbacks.ModelCheckpoint(results_path + '/' + model_name + '.h5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
early = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=min_delta, patience=patience, verbose=1, mode='auto')

history = model.fit(X_train, y_train, validation_data = [X_val, y_val], epochs = max_epoch, callbacks = [checkpoint, early], shuffle = True)

# Accuracy
fig1 = plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.grid()
fig1.savefig(results_path + '/' + model_name + '_model_accuracy.png')
plt.show()
# Loss
fig2 = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.grid()
fig2.savefig(results_path + '/' + model_name + '_model_loss.png')
plt.show()
# Out:
# Epoch 1/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.6644 - accuracy: 0.6436 - auc: 0.6955
# Epoch 1: val_accuracy improved from -inf to 0.72078, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 16s 7ms/step - loss: 0.6644 - accuracy: 0.6436 - auc: 0.6955 - val_loss: 0.6490 - val_accuracy: 0.7208 - val_auc: 0.8097
# Epoch 2/1000
# 430/433 [============================>.] - ETA: 0s - loss: 0.5445 - accuracy: 0.7416 - auc: 0.8165
# Epoch 2: val_accuracy improved from 0.72078 to 0.72727, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 8ms/step - loss: 0.5439 - accuracy: 0.7421 - auc: 0.8170 - val_loss: 0.7384 - val_accuracy: 0.7273 - val_auc: 0.8147
# Epoch 3/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.4897 - accuracy: 0.7863 - auc: 0.8576
# Epoch 3: val_accuracy improved from 0.72727 to 0.81169, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 4s 8ms/step - loss: 0.4896 - accuracy: 0.7864 - auc: 0.8577 - val_loss: 0.6420 - val_accuracy: 0.8117 - val_auc: 0.8793
# Epoch 4/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.4563 - accuracy: 0.8007 - auc: 0.8752
# Epoch 4: val_accuracy improved from 0.81169 to 0.82468, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.4563 - accuracy: 0.8007 - auc: 0.8752 - val_loss: 0.7098 - val_accuracy: 0.8247 - val_auc: 0.8940
# Epoch 5/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.4333 - accuracy: 0.8190 - auc: 0.8902
# Epoch 5: val_accuracy did not improve from 0.82468
# 433/433 [==============================] - 3s 6ms/step - loss: 0.4335 - accuracy: 0.8189 - auc: 0.8901 - val_loss: 0.6967 - val_accuracy: 0.8247 - val_auc: 0.9013
# Epoch 6/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.4208 - accuracy: 0.8206 - auc: 0.8950
# Epoch 6: val_accuracy did not improve from 0.82468
# 433/433 [==============================] - 3s 6ms/step - loss: 0.4199 - accuracy: 0.8206 - auc: 0.8954 - val_loss: 0.7861 - val_accuracy: 0.8247 - val_auc: 0.9012
# Epoch 7/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8252 - auc: 0.9010
# Epoch 7: val_accuracy did not improve from 0.82468
# 433/433 [==============================] - 3s 6ms/step - loss: 0.4090 - accuracy: 0.8252 - auc: 0.9010 - val_loss: 0.7834 - val_accuracy: 0.8117 - val_auc: 0.9086
# Epoch 8/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8376 - auc: 0.9109
# Epoch 8: val_accuracy did not improve from 0.82468
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3864 - accuracy: 0.8376 - auc: 0.9109 - val_loss: 0.7464 - val_accuracy: 0.7987 - val_auc: 0.9021
# Epoch 9/1000
# 429/433 [============================>.] - ETA: 0s - loss: 0.3735 - accuracy: 0.8447 - auc: 0.9172
# Epoch 9: val_accuracy did not improve from 0.82468
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3736 - accuracy: 0.8446 - auc: 0.9171 - val_loss: 0.8308 - val_accuracy: 0.8117 - val_auc: 0.9081
# Epoch 10/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.3734 - accuracy: 0.8437 - auc: 0.9162
# Epoch 10: val_accuracy improved from 0.82468 to 0.83766, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3734 - accuracy: 0.8437 - auc: 0.9162 - val_loss: 0.8066 - val_accuracy: 0.8377 - val_auc: 0.9175
# Epoch 11/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.3609 - accuracy: 0.8510 - auc: 0.9216
# Epoch 11: val_accuracy did not improve from 0.83766
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3607 - accuracy: 0.8510 - auc: 0.9217 - val_loss: 0.8226 - val_accuracy: 0.8247 - val_auc: 0.9187
# Epoch 12/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.3569 - accuracy: 0.8559 - auc: 0.9244
# Epoch 12: val_accuracy did not improve from 0.83766
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3569 - accuracy: 0.8559 - auc: 0.9244 - val_loss: 0.7556 - val_accuracy: 0.8312 - val_auc: 0.9233
# Epoch 13/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.3509 - accuracy: 0.8490 - auc: 0.9250
# Epoch 13: val_accuracy did not improve from 0.83766
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3507 - accuracy: 0.8493 - auc: 0.9251 - val_loss: 0.7887 - val_accuracy: 0.8247 - val_auc: 0.9224
# Epoch 14/1000
# 425/433 [============================>.] - ETA: 0s - loss: 0.3431 - accuracy: 0.8567 - auc: 0.9290
# Epoch 14: val_accuracy did not improve from 0.83766
# 433/433 [==============================] - 3s 6ms/step - loss: 0.3427 - accuracy: 0.8572 - auc: 0.9292 - val_loss: 0.7395 - val_accuracy: 0.8117 - val_auc: 0.9182
# Epoch 15/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8617 - auc: 0.9315
# Epoch 15: val_accuracy improved from 0.83766 to 0.84416, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.
val_accuracy did not improve from 0.84416
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2871 - accuracy: 0.8801 - auc: 0.9485 - val_loss: 0.7831 - val_accuracy: 0.8377 - val_auc: 0.9290
# Epoch 30/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.2878 - accuracy: 0.8797 - auc: 0.9478
# Epoch 30: val_accuracy did not improve from 0.84416
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2882 - accuracy: 0.8797 - auc: 0.9477 - val_loss: 0.9709 - val_accuracy: 0.8377 - val_auc: 0.9138
# Epoch 31/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.2855 - accuracy: 0.8810 - auc: 0.9490
# Epoch 31: val_accuracy improved from 0.84416 to 0.85065, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2860 - accuracy: 0.8809 - auc: 0.9488 - val_loss: 0.8345 - val_accuracy: 0.8506 - val_auc: 0.9248
# Epoch 32/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.2795 - accuracy: 0.8844 - auc: 0.9512
# Epoch 32: val_accuracy improved from 0.85065 to 0.85714, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2786 - accuracy: 0.8849 - auc: 0.9516 - val_loss: 0.8941 - val_accuracy: 0.8571 - val_auc: 0.9359
# Epoch 33/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.2776 - accuracy: 0.8847 - auc: 0.9511
# Epoch 33: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2773 - accuracy: 0.8848 - auc: 0.9512 - val_loss: 0.9706 - val_accuracy: 0.8571 - val_auc: 0.9195
# Epoch 34/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.2764 - accuracy: 0.8840 - auc: 0.9518
# Epoch 34: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2766 - accuracy: 0.8837 - auc: 0.9517 - val_loss: 0.8612 - val_accuracy: 0.8506 - val_auc: 0.9298
# Epoch 35/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.2745 - accuracy: 0.8848 - auc: 0.9524
# Epoch 35: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2751 - accuracy: 0.8847 - auc: 0.9522 - val_loss: 0.6982 - val_accuracy: 0.8506 - val_auc: 0.9223
# Epoch 36/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.8877 - auc: 0.9527
# Epoch 36: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2752 - accuracy: 0.8877 - auc: 0.9527 - val_loss: 0.7263 - val_accuracy: 0.8312 - val_auc: 0.9341
# Epoch 37/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.2692 - accuracy: 0.8877 - auc: 0.9539
# Epoch 37: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2689 - accuracy: 0.8877 - auc: 0.9539 - val_loss: 0.8226 - val_accuracy: 0.8506 - val_auc: 0.9307
# Epoch 38/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.2663 - accuracy: 0.8891 - auc: 0.9549
# Epoch 38: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2662 - accuracy: 0.8892 - auc: 0.9549 - val_loss: 0.7780 - val_accuracy: 0.8506 - val_auc: 0.9348
# Epoch 39/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.8892 - auc: 0.9543
# Epoch 39: val_accuracy did not improve from 0.85714
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2680 - accuracy: 0.8892 - auc: 0.9543 - val_loss: 0.8458 - val_accuracy: 0.8442 - val_auc: 0.9328
# Epoch 40/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.2660 - accuracy: 0.8874 - auc: 0.9548
# Epoch 40: val_accuracy improved from 0.85714 to 0.87013, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2662 - accuracy: 0.8871 - auc: 0.9547 - val_loss: 0.8754 - val_accuracy: 0.8701 - val_auc: 0.9341
# Epoch 41/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.2606 - accuracy: 0.8904 - auc: 0.9557
# Epoch 41: val_accuracy did not improve from 0.87013
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2612 - accuracy: 0.8903 - auc: 0.9556 - val_loss: 0.7583 - val_accuracy: 0.8571 - val_auc: 0.9389
# Epoch 42/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.87013
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2373 - accuracy: 0.9004 - auc: 0.9631 - val_loss: 0.8551 - val_accuracy: 0.8506 - val_auc: 0.9214
# Epoch 56/1000
# 425/433 [============================>.] - ETA: 0s - loss: 0.2495 - accuracy: 0.8960 - auc: 0.9598
# Epoch 56: val_accuracy did not improve from 0.87013
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2501 - accuracy: 0.8957 - auc: 0.9596 - val_loss: 0.6134 - val_accuracy: 0.8442 - val_auc: 0.9318
# Epoch 57/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.2375 - accuracy: 0.8991 - auc: 0.9632
# Epoch 57: val_accuracy did not improve from 0.87013
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2375 - accuracy: 0.8991 - auc: 0.9632 - val_loss: 0.5639 - val_accuracy: 0.8571 - val_auc: 0.9367
# Epoch 58/1000
# 429/433 [============================>.] - ETA: 0s - loss: 0.2320 - accuracy: 0.9023 - auc: 0.9642
# Epoch 58: val_accuracy did not improve from 0.87013
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2325 - accuracy: 0.9021 - auc: 0.9640 - val_loss: 0.5176 - val_accuracy: 0.8571 - val_auc: 0.9334
# Epoch 59/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.2320 - accuracy: 0.9010 - auc: 0.9640
# Epoch 59: val_accuracy improved from 0.87013 to 0.87662, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2322 - accuracy: 0.9009 - auc: 0.9640 - val_loss: 0.6892 - val_accuracy: 0.8766 - val_auc: 0.9361
# Epoch 60/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.8995 - auc: 0.9625
# Epoch 60: val_accuracy did not improve from 0.87662
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2394 - accuracy: 0.8995 - auc: 0.9625 - val_loss: 0.6931 - val_accuracy: 0.8506 - val_auc: 0.9352
# Epoch 61/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.2349 - accuracy: 0.9022 - auc: 0.9644
# Epoch 61: val_accuracy did not improve from 0.87662
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2349 - accuracy: 0.9021 - auc: 0.9644 - val_loss: 0.6547 - val_accuracy: 0.8442 - val_auc: 0.9332
# Epoch 62/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.2266 - accuracy: 0.9034 - auc: 0.9660
# Epoch 62: val_accuracy improved from 0.87662 to 0.88312, saving model to /content/microbox_fft_xyz_300_data_aug_1.h5
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2265 - accuracy: 0.9035 - auc: 0.9660 - val_loss: 0.6952 - val_accuracy: 0.8831 - val_auc: 0.9177
# Epoch 63/1000
# 425/433 [============================>.] - ETA: 0s - loss: 0.2378 - accuracy: 0.9003 - auc: 0.9633
# Epoch 63: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2381 - accuracy: 0.9003 - auc: 0.9630 - val_loss: 0.7633 - val_accuracy: 0.8701 - val_auc: 0.9215
# Epoch 64/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9028 - auc: 0.9656
# Epoch 64: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2336 - accuracy: 0.9028 - auc: 0.9656 - val_loss: 0.6421 - val_accuracy: 0.8506 - val_auc: 0.9329
# Epoch 65/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9044 - auc: 0.9658
# Epoch 65: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2265 - accuracy: 0.9044 - auc: 0.9658 - val_loss: 1.0387 - val_accuracy: 0.8052 - val_auc: 0.8851
# Epoch 66/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.2273 - accuracy: 0.9015 - auc: 0.9662
# Epoch 66: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2278 - accuracy: 0.9012 - auc: 0.9660 - val_loss: 0.6166 - val_accuracy: 0.8571 - val_auc: 0.9210
# Epoch 67/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.2281 - accuracy: 0.9015 - auc: 0.9656
# Epoch 67: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2281 - accuracy: 0.9014 - auc: 0.9656 - val_loss: 0.5838 - val_accuracy: 0.8571 - val_auc: 0.9360
# Epoch 68/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.2219 - accuracy: 0.9027 - auc: 0.9673
# Epoch 68: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.
val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2049 - accuracy: 0.9131 - auc: 0.9717 - val_loss: 0.7536 - val_accuracy: 0.8442 - val_auc: 0.9171
# Epoch 97/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9144 - auc: 0.9740
# Epoch 97: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1964 - accuracy: 0.9143 - auc: 0.9741 - val_loss: 0.6182 - val_accuracy: 0.8636 - val_auc: 0.9276
# Epoch 98/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.1989 - accuracy: 0.9174 - auc: 0.9732
# Epoch 98: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1995 - accuracy: 0.9172 - auc: 0.9730 - val_loss: 0.7137 - val_accuracy: 0.8442 - val_auc: 0.9131
# Epoch 99/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9132 - auc: 0.9722
# Epoch 99: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2043 - accuracy: 0.9132 - auc: 0.9722 - val_loss: 0.6492 - val_accuracy: 0.8571 - val_auc: 0.9169
# Epoch 100/1000
# 425/433 [============================>.] - ETA: 0s - loss: 0.2032 - accuracy: 0.9132 - auc: 0.9719
# Epoch 100: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.2026 - accuracy: 0.9135 - auc: 0.9721 - val_loss: 0.6691 - val_accuracy: 0.8506 - val_auc: 0.9226
# Epoch 101/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9152 - auc: 0.9733
# Epoch 101: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1989 - accuracy: 0.9152 - auc: 0.9733 - val_loss: 0.6389 - val_accuracy: 0.8701 - val_auc: 0.9280
# Epoch 102/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9169 - auc: 0.9732
# Epoch 102: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1968 - accuracy: 0.9172 - auc: 0.9733 - val_loss: 0.6806 - val_accuracy: 0.8571 - val_auc: 0.9213
# Epoch 103/1000
# 429/433 [============================>.] - ETA: 0s - loss: 0.1961 - accuracy: 0.9165 - auc: 0.9740
# Epoch 103: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1959 - accuracy: 0.9166 - auc: 0.9741 - val_loss: 0.5781 - val_accuracy: 0.8506 - val_auc: 0.9212
# Epoch 104/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.1918 - accuracy: 0.9204 - auc: 0.9746
# Epoch 104: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 4s 8ms/step - loss: 0.1918 - accuracy: 0.9204 - auc: 0.9746 - val_loss: 0.7267 - val_accuracy: 0.8442 - val_auc: 0.9277
# Epoch 105/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.1955 - accuracy: 0.9165 - auc: 0.9739
# Epoch 105: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1950 - accuracy: 0.9166 - auc: 0.9740 - val_loss: 0.6032 - val_accuracy: 0.8442 - val_auc: 0.9241
# Epoch 106/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.1943 - accuracy: 0.9174 - auc: 0.9741
# Epoch 106: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1942 - accuracy: 0.9174 - auc: 0.9741 - val_loss: 0.8175 - val_accuracy: 0.8506 - val_auc: 0.9118
# Epoch 107/1000
# 430/433 [============================>.] - ETA: 0s - loss: 0.1929 - accuracy: 0.9184 - auc: 0.9739
# Epoch 107: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1928 - accuracy: 0.9182 - auc: 0.9739 - val_loss: 0.9183 - val_accuracy: 0.8442 - val_auc: 0.9078
# Epoch 108/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.9177 - auc: 0.9755
# Epoch 108: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1905 - accuracy: 0.9180 - auc: 0.9756 - val_loss: 0.6716 - val_accuracy: 0.8312 - val_auc: 0.9101
# Epoch 109/1000
# 425/433 [============================>.] - ETA: 0s - loss: 0.1877 - accuracy: 0.9207 - auc: 0.9755
# Epoch 109: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1875 - accuracy: 0.9206 - auc: 0.9755 - val_loss: 0.7405 - val_accuracy: 0.8571 - val_auc: 0.9253
# Epoch 110/1000
# 433/433 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9173 - auc: 0.9747
# Epoch 110: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1936 - accuracy: 0.9173 - auc: 0.9747 - val_loss: 0.7670 - val_accuracy: 0.8442 - val_auc: 0.9191
# Epoch 111/1000
# 429/433 [============================>.] - ETA: 0s - loss: 0.1912 - accuracy: 0.9197 - auc: 0.9749
# Epoch 111: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1915 - accuracy: 0.9195 - auc: 0.9748 - val_loss: 0.7854 - val_accuracy: 0.8377 - val_auc: 0.9144
# Epoch 112/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.1892 - accuracy: 0.9183 - auc: 0.9748
# Epoch 112: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1887 - accuracy: 0.9186 - auc: 0.9749 - val_loss: 0.6753 - val_accuracy: 0.8571 - val_auc: 0.9250
# Epoch 113/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9175 - auc: 0.9727
# Epoch 113: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 6ms/step - loss: 0.1983 - accuracy: 0.9176 - auc: 0.9727 - val_loss: 0.6350 - val_accuracy: 0.8377 - val_auc: 0.9093
# Epoch 114/1000
# 428/433 [============================>.] - ETA: 0s - loss: 0.1931 - accuracy: 0.9183 - auc: 0.9748
# Epoch 114: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1928 - accuracy: 0.9186 - auc: 0.9749 - val_loss: 0.5913 - val_accuracy: 0.8442 - val_auc: 0.9268
# Epoch 115/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.1899 - accuracy: 0.9208 - auc: 0.9755
# Epoch 115: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1908 - accuracy: 0.9199 - auc: 0.9753 - val_loss: 0.6944 - val_accuracy: 0.8506 - val_auc: 0.8982
# Epoch 116/1000
# 429/433 [============================>.] - ETA: 0s - loss: 0.1858 - accuracy: 0.9200 - auc: 0.9760
# Epoch 116: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1863 - accuracy: 0.9200 - auc: 0.9759 - val_loss: 0.6711 - val_accuracy: 0.8571 - val_auc: 0.9288
# Epoch 117/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.1907 - accuracy: 0.9195 - auc: 0.9758
# Epoch 117: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1908 - accuracy: 0.9194 - auc: 0.9758 - val_loss: 0.6899 - val_accuracy: 0.8506 - val_auc: 0.9195
# Epoch 118/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.1892 - accuracy: 0.9186 - auc: 0.9756
# Epoch 118: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1891 - accuracy: 0.9187 - auc: 0.9755 - val_loss: 0.6783 - val_accuracy: 0.8442 - val_auc: 0.9195
# Epoch 119/1000
# 431/433 [============================>.] - ETA: 0s - loss: 0.1904 - accuracy: 0.9165 - auc: 0.9754
# Epoch 119: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1903 - accuracy: 0.9165 - auc: 0.9755 - val_loss: 0.6442 - val_accuracy: 0.8377 - val_auc: 0.9131
# Epoch 120/1000
# 427/433 [============================>.] - ETA: 0s - loss: 0.1834 - accuracy: 0.9220 - auc: 0.9767
# Epoch 120: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1839 - accuracy: 0.9217 - auc: 0.9766 - val_loss: 0.6312 - val_accuracy: 0.8377 - val_auc: 0.9168
# Epoch 121/1000
# 432/433 [============================>.] - ETA: 0s - loss: 0.1827 - accuracy: 0.9235 - auc: 0.9763
# Epoch 121: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1825 - accuracy: 0.9235 - auc: 0.9763 - val_loss: 0.6664 - val_accuracy: 0.8571 - val_auc: 0.9114
# Epoch 122/1000
# 426/433 [============================>.] - ETA: 0s - loss: 0.1880 - accuracy: 0.9196 - auc: 0.9762
# Epoch 122: val_accuracy did not improve from 0.88312
# 433/433 [==============================] - 3s 7ms/step - loss: 0.1875 - accuracy: 0.9201 - auc: 0.9764 - val_loss: 0.6936 - val_accuracy: 0.8506 - val_auc: 0.9297
# Epoch 122: early stopping

# %%
# Test
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from matplotlib import pyplot as plt
from tensorflow import keras
import seaborn as sns
import pandas as pd


model = keras.models.load_model(results_path + '/' + model_name + '.h5')
model.summary()
results = model.evaluate(X_test, y_test)

print('\nTest Loss, Test Accuracy, Test AUC:', results)

# Generate confusion matrix and compute metrics
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
conf_mat = confusion_matrix(y_test.argmax(axis=1), y_pred)
tn, fp, fn, tp = conf_mat.ravel()
precision = precision_score(y_test.argmax(axis=1), y_pred)
recall = recall_score(y_test.argmax(axis=1), y_pred)
f1_score = f1_score(y_test.argmax(axis=1), y_pred)

print('\nPrecision: ' + str(precision))
print('Recall: ' + str(recall))
print('F1-score: ' + str(f1_score))
print('\nTrue Negatives: ' + str(tn))
print('False Positives: ' + str(fp))
print('False Negatives: ' + str(fn))
print('True Positives: ' + str(tp) + '\n')

fig = plt.figure()
sns.heatmap(conf_mat, annot=True, fmt="d",cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion matrix')
fig.savefig(results_path + '/' + model_name + '_confusion_matrix.png')
plt.show()

data = {'a': [results[0], results[1], results[2], precision, recall, f1_score, tn, fp, fn, tp]}
df = pd.DataFrame(data=data, index=['Test Loss', 'Test Accuracy', 'Test AUC', 'Precision', 'Recall', 'F1-score', 'True Negatives', 'False Positives', 'False Negatives', 'True Positives'])
df.to_csv(results_path + '/' + model_name + '_results.csv', header=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 291, 100)          3100
#
#  max_pooling1d (MaxPooling1D  (None, 14, 100)          0
#  )
#
#  dropout (Dropout)           (None, 14, 100)           0
#
#  conv1d_1 (Conv1D)           (None, 13, 50)            10050
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 50)            0
#  1D)
#
#  dropout_1 (Dropout)         (None, 2, 50)             0
#
#  conv1d_2 (Conv1D)           (None, 1, 25)             2525
#
#  global_max_pooling1d (Globa  (None, 25)               0
#  lMaxPooling1D)
#
#  dropout_2 (Dropout)         (None, 25)                0
#
#  dense (Dense)               (None, 2)                 52
#
# =================================================================
# Total params: 15,727
# Trainable params: 15,727
# Non-trainable params: 0
# _________________________________________________________________
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4497 - accuracy: 0.8368 - auc: 0.9042
#
# Test Loss, Test Accuracy, Test AUC: [0.4497027099132538, 0.8367875814437866, 0.904228925704956]
#
# Precision: 0.8735632183908046
# Recall: 0.7875647668393783
# F1-score: 0.8283378746594007
#
# True Negatives: 171
# False Positives: 22
# False Negatives: 41
# True Positives: 152

# %%
# Save test dataset
import csv
import os


if len(os.listdir(test_dataset_path + '/false')) == 0 and len(os.listdir(test_dataset_path + '/true')) == 0:
  for i in range(0,len(X_test)):
    if y_test[i][1] == 1:
      test_class = "true"
    else:
      test_class = "false"
    with open(test_dataset_path + '/' + test_class + '/' + test_class + '_' + str(i+1) + '.csv', 'w') as csvfile:
      writer = csv.writer(csvfile)
      writer.writerow(["","",""])
      for j in range(0, len(X_test[0])):
        writer.writerow([str(X_test[i][j][0]), str(X_test[i][j][1]), str(X_test[i][j][2])])
      writer.writerow(["", "", ""])
