# %% [markdown]
# See https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf for more information about 1d convolutions and time series classification

# %%
# Install packages
# !pip install samplerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting samplerate
#   Downloading samplerate-0.1.0-py2.py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 16.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from samplerate) (1.21.6)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from samplerate) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.0->samplerate) (2.21)
# Installing collected packages: samplerate
# Successfully installed samplerate-0.1.0

# %%
# Check if tensorflow finds the runtime GPU
import tensorflow as tf


print(tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('GPU device not found')
else:
  print('Found GPU at: {}'.format(device_name))
# Out:
# 2.8.2
# Found GPU at: /device:GPU:0

# %%
# Clone the repository
# Out:
# Cloning into 'fc_crash-detection'...
# remote: Enumerating objects: 18779, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 18779 (delta 13), reused 9 (delta 4), pack-reused 18749
# Receiving objects: 100% (18779/18779), 2.00 GiB | 24.63 MiB/s, done.
# Resolving deltas: 100% (835/835), done.
# Checking out files: 100% (16051/16051), done.

# %%
# Mount Google Drive
from google.colab import drive


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set params
dataset_path = '/content/fc_crash-detection/crash-dataset-csv/infobox'
test_dataset_path = '/content/drive/MyDrive/norm_dataset/infobox' # Where to save test set
results_path = '/content/drive/MyDrive'
model_name = 'infobox_xy_1200_norm_1' # In results_path
mode = "time" # time or fft
test_split = 0.05
validation_split = 0.1
max_epoch = 1000
min_delta = 0
patience = 100

# %%
# Define some functions
from tqdm.notebook import tqdm
from scipy.fft import fft
import numpy as np
import pandas as pd
import samplerate
import glob
import os


def preprocess_infobox(entry):
  # Decide hardware version based on recording lenght
  # rev 1
  if (len(entry)) > 3100:
    # Get records for which sampling freq is 400Hz
    # Get only col 4 and 5 (filtered x and y accelerometers)
    #loaded_entry = entry.values[500:2900,4:6]
    # Make infobox sample similar to microbox
    loaded_entry = entry.values[900:2100,4:6]

  # rev 2,3
  else:
    if (len(entry)) > 3050:
      loaded_entry = entry.values[59:3059,4:6]
    else:
      loaded_entry = entry.values[0:3000,4:6]

    # All records have sampling freq of 1000Hz
    # Get only col 4 and 5 (filtered x and y accelerometers)
    #loaded_entry = entry.values[59:3059,4:6]
    
    # Resample 1000Hz to 400Hz -> ratio = out_freq / in_freq
    ratio = 0.4
    converter = 'sinc_best'  # Or 'sinc_fastest', ...
    loaded_entry = samplerate.resample(loaded_entry, ratio, converter)

    # Pad matrix length difference with the last recorded value for each axis with mode = 'edge'
    #diff = 2400 - len(loaded_entry)
    # Pad_width format for 2d vectors: ((top, bottom), (left, right))
    #loaded_entry = np.pad(loaded_entry, ((0,diff),(0,0)), mode = 'edge')

  # 3000 length recording have cleaner sensor data!!

  return loaded_entry


def get_dataset(path):

  entry_list = []

  files_list = glob.glob(os.path.join(path, "*.csv"))
  # Load every csv inside path as a numpy matrix, preprocess and create a list
  for filename in tqdm(files_list):
    ds_entry = pd.read_csv(filename, index_col=None, header=0)
    ds_entry_processed = preprocess_infobox(ds_entry)

    ds_entry_norm = np.empty([len(ds_entry_processed), 1])
    for i in range (0, len(ds_entry_processed)):
      ds_entry_norm[i] = np.linalg.norm(ds_entry_processed[i,:])

    if mode == "fft": # If mode fft, apply fast Fourier transform

      fft_ = fft(ds_entry_norm[:,0])

      d_ = np.absolute(fft_)

      ds_entry_fft = np.stack([d_], axis=1)
      entry_list.append(ds_entry_fft)

    if mode == "time":
      entry_list.append(ds_entry_norm)
  
  # Convert list to a numpy array. Cast to float32 to avoid errors on fit
  ds_array = np.asarray(entry_list).astype('float32')

  return ds_array

# %%
# Load data
import numpy as np


ds_false = get_dataset(dataset_path + '/false')
ds_true = get_dataset(dataset_path + '/true')

# Build all-false labels (one hot encoding, two classes, two columns)
ds_false_labels = np.zeros((len(ds_false),2))
# Set all first column to one
ds_false_labels[:,0] = 1
print("False-class data:")
print(ds_false.shape)
print(ds_false_labels.shape)

# Build all-true labels (one hot encoding, two classes, two columns)
ds_true_labels = np.zeros((len(ds_true),2))
# Set all second column to one
ds_true_labels[:,1] = 1
print("\nTrue-class data:")
print(ds_true.shape)
print(ds_true_labels.shape)

# Concatenate false-class/true-class data and labels
ds_all = np.concatenate((ds_false, ds_true), axis = 0)
ds_all_labels = np.concatenate((ds_false_labels, ds_true_labels), axis = 0)
print("\nAll data:")
print(ds_all.shape)
print(ds_all_labels.shape)
del ds_false, ds_true, ds_false_labels, ds_true_labels
# Out:
#   0%|          | 0/3045 [00:00<?, ?it/s]
#   0%|          | 0/3045 [00:00<?, ?it/s]
# False-class data:
# (3045, 1200, 1)
# (3045, 2)
#
# True-class data:
# (3045, 1200, 1)
# (3045, 2)
#
# All data:
# (6090, 1200, 1)
# (6090, 2)

# %%
# Plot a single sample of data
from matplotlib import pyplot as plt
import numpy as np
import random


sample = random.randint(0, ds_all.shape[0])
x = np.arange(0,len(ds_all[sample]))

fig = plt.figure(figsize=(16,8))
plt.plot(x, ds_all[sample,:,0])
plt.show()

# %%
# Create train and test splits
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(ds_all, ds_all_labels, test_size = test_split)

print("Train split:")
print(X_train.shape)
print(y_train.shape)

print("\nTest split:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Train split:
# (5785, 1200, 1)
# (5785, 2)
#
# Test split:
# (305, 1200, 1)
# (305, 2)

# %%
# Create the model
import tensorflow as tf
from tensorflow.keras.layers import Activation,Dense,Dropout,Conv1D,Flatten,MaxPooling1D,GlobalAveragePooling1D


# Model definition
model = tf.keras.Sequential()

input_shape=(X_train.shape[1],X_train.shape[2])
model.add(Conv1D(110, 20, activation='relu', input_shape=input_shape)) #120, 20
#model.add(Conv1D(100, 10, activation='relu'))
model.add(MaxPooling1D(16))
model.add(Dropout(0.5))
model.add(Conv1D(100, 10, activation='relu')) #100, 10
#model.add(Conv1D(80, 10, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(y_train.shape[1], activation='softmax'))

# Define optimizer, learning rate, and compile model
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', 'AUC'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1181, 110)         2310
#
#  max_pooling1d (MaxPooling1D  (None, 73, 110)          0
#  )
#
#  dropout (Dropout)           (None, 73, 110)           0
#
#  conv1d_1 (Conv1D)           (None, 64, 100)           110100
#
#  global_average_pooling1d (G  (None, 100)              0
#  lobalAveragePooling1D)
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 2)                 202
#
# =================================================================
# Total params: 112,612
# Trainable params: 112,612
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train
from matplotlib import pyplot as plt
import tensorflow as tf


checkpoint = tf.keras.callbacks.ModelCheckpoint(results_path + '/' + model_name + '.h5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
early = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=min_delta, patience=patience, verbose=1, mode='auto')

history = model.fit(X_train, y_train, validation_split = validation_split, epochs = max_epoch, callbacks = [checkpoint, early], shuffle = True)

# Accuracy
fig1 = plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.grid()
fig1.savefig(results_path + '/' + model_name + '_model_accuracy.png')
plt.show()
# Loss
fig2 = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.grid()
fig2.savefig(results_path + '/' + model_name + '_model_loss.png')
plt.show()
# Out:
# Epoch 1/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.6488 - accuracy: 0.6715 - auc: 0.7300
# Epoch 1: val_accuracy improved from -inf to 0.74611, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 15s 12ms/step - loss: 0.6488 - accuracy: 0.6715 - auc: 0.7300 - val_loss: 0.5392 - val_accuracy: 0.7461 - val_auc: 0.8291
# Epoch 2/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.5236 - accuracy: 0.7801 - auc: 0.8450
# Epoch 2: val_accuracy improved from 0.74611 to 0.82556, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.5246 - accuracy: 0.7803 - auc: 0.8450 - val_loss: 0.4490 - val_accuracy: 0.8256 - val_auc: 0.8794
# Epoch 3/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.4751 - accuracy: 0.7976 - auc: 0.8695
# Epoch 3: val_accuracy improved from 0.82556 to 0.83420, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4768 - accuracy: 0.7958 - auc: 0.8687 - val_loss: 0.4352 - val_accuracy: 0.8342 - val_auc: 0.8889
# Epoch 4/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.4549 - accuracy: 0.8154 - auc: 0.8795
# Epoch 4: val_accuracy improved from 0.83420 to 0.83592, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4540 - accuracy: 0.8154 - auc: 0.8797 - val_loss: 0.4266 - val_accuracy: 0.8359 - val_auc: 0.8909
# Epoch 5/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.4428 - accuracy: 0.8119 - auc: 0.8842
# Epoch 5: val_accuracy did not improve from 0.83592
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4424 - accuracy: 0.8119 - auc: 0.8845 - val_loss: 0.4182 - val_accuracy: 0.8325 - val_auc: 0.8901
# Epoch 6/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.4240 - accuracy: 0.8250 - auc: 0.8939
# Epoch 6: val_accuracy improved from 0.83592 to 0.84629, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4224 - accuracy: 0.8265 - auc: 0.8948 - val_loss: 0.4026 - val_accuracy: 0.8463 - val_auc: 0.9017
# Epoch 7/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.4160 - accuracy: 0.8285 - auc: 0.8982
# Epoch 7: val_accuracy did not improve from 0.84629
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4146 - accuracy: 0.8294 - auc: 0.8988 - val_loss: 0.3955 - val_accuracy: 0.8428 - val_auc: 0.9050
# Epoch 8/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.4044 - accuracy: 0.8367 - auc: 0.9030
# Epoch 8: val_accuracy did not improve from 0.84629
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4048 - accuracy: 0.8358 - auc: 0.9025 - val_loss: 0.3877 - val_accuracy: 0.8428 - val_auc: 0.9056
# Epoch 9/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3972 - accuracy: 0.8432 - auc: 0.9068
# Epoch 9: val_accuracy did not improve from 0.84629
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3973 - accuracy: 0.8431 - auc: 0.9066 - val_loss: 0.3798 - val_accuracy: 0.8446 - val_auc: 0.9101
# Epoch 10/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.3992 - accuracy: 0.8353 - auc: 0.9059
# Epoch 10: val_accuracy improved from 0.84629 to 0.84801, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4000 - accuracy: 0.8362 - auc: 0.9058 - val_loss: 0.3786 - val_accuracy: 0.8480 - val_auc: 0.9119
# Epoch 11/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3964 - accuracy: 0.8434 - auc: 0.9076
# Epoch 11: val_accuracy did not improve from 0.84801
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3967 - accuracy: 0.8425 - auc: 0.9073 - val_loss: 0.3957 - val_accuracy: 0.8325 - val_auc: 0.9015
# Epoch 12/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3867 - accuracy: 0.8491 - auc: 0.9096
# Epoch 12: val_accuracy did not improve from 0.84801
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3870 - accuracy: 0.8490 - auc: 0.9095 - val_loss: 0.3809 - val_accuracy: 0.8428 - val_auc: 0.9105
# Epoch 13/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3818 - accuracy: 0.8473 - auc: 0.9138
# Epoch 13: val_accuracy improved from 0.84801 to 0.85320, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3829 - accuracy: 0.8456 - auc: 0.9132 - val_loss: 0.3694 - val_accuracy: 0.8532 - val_auc: 0.9141
# Epoch 14/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3777 - accuracy: 0.8459 - auc: 0.9144
# Epoch 14: val_accuracy did not improve from 0.85320
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3768 - accuracy: 0.8467 - auc: 0.9148 - val_loss: 0.3819 - val_accuracy: 0.8480 - val_auc: 0.9117
# Epoch 15/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3668 - accuracy: 0.8518 - auc: 0.9191
# Epoch 15: val_accuracy improved from 0.85320 to 0.85665, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3659 - accuracy: 0.8517 - auc: 0.9195 - val_loss: 0.3725 - val_accuracy: 0.8566 - val_auc: 0.9146
# Epoch 16/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3809 - accuracy: 0.8502 - auc: 0.9163
# Epoch 16: val_accuracy improved from 0.85665 to 0.86356, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3808 - accuracy: 0.8504 - auc: 0.9166 - val_loss: 0.3576 - val_accuracy: 0.8636 - val_auc: 0.9178
# Epoch 17/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3742 - accuracy: 0.8529 - auc: 0.9170
# Epoch 17: val_accuracy did not improve from 0.86356
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3727 - accuracy: 0.8544 - auc: 0.9178 - val_loss: 0.3697 - val_accuracy: 0.8549 - val_auc: 0.9143
# Epoch 18/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3664 - accuracy: 0.8571 - auc: 0.9202
# Epoch 18: val_accuracy did not improve from 0.86356
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3652 - accuracy: 0.8579 - auc: 0.9207 - val_loss: 0.3608 - val_accuracy: 0.8636 - val_auc: 0.9199
# Epoch 19/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3618 - accuracy: 0.8615 - auc: 0.9227
# Epoch 19: val_accuracy did not improve from 0.86356
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3593 - accuracy: 0.8630 - auc: 0.9238 - val_loss: 0.3502 - val_accuracy: 0.8601 - val_auc: 0.9215
# Epoch 20/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.3588 - accuracy: 0.8598 - auc: 0.9219
# Epoch 20: val_accuracy did not improve from 0.86356
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3597 - accuracy: 0.8592 - auc: 0.9214 - val_loss: 0.3668 - val_accuracy: 0.8618 - val_auc: 0.9147
# Epoch 21/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3535 - accuracy: 0.8588 - auc: 0.9247
# Epoch 21: val_accuracy did not improve from 0.86356
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3535 - accuracy: 0.8580 - auc: 0.9246 - val_loss: 0.3555 - val_accuracy: 0.8636 - val_auc: 0.9180
# Epoch 22/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3528 - accuracy: 0.8679 - auc: 0.9236
# Epoch 22: val_accuracy improved from 0.86356 to 0.86528, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3530 - accuracy: 0.8673 - auc: 0.9236 - val_loss: 0.3536 - val_accuracy: 0.8653 - val_auc: 0.9213
# Epoch 23/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3525 - accuracy: 0.8641 - auc: 0.9253
# Epoch 23: val_accuracy did not improve from 0.86528
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3503 - accuracy: 0.8646 - auc: 0.9261 - val_loss: 0.3602 - val_accuracy: 0.8566 - val_auc: 0.9176
# Epoch 24/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8681 - auc: 0.9269
# Epoch 24: val_accuracy improved from 0.86528 to 0.87219, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3506 - accuracy: 0.8680 - auc: 0.9267 - val_loss: 0.3427 - val_accuracy: 0.8722 - val_auc: 0.9259
# Epoch 25/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3518 - accuracy: 0.8630 - auc: 0.9252
# Epoch 25: val_accuracy did not improve from 0.87219
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3526 - accuracy: 0.8627 - auc: 0.9250 - val_loss: 0.3569 - val_accuracy: 0.8653 - val_auc: 0.9168
# Epoch 26/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.8691 - auc: 0.9291
# Epoch 26: val_accuracy did not improve from 0.87219
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3437 - accuracy: 0.8688 - auc: 0.9289 - val_loss: 0.3441 - val_accuracy: 0.8618 - val_auc: 0.9258
# Epoch 27/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3377 - accuracy: 0.8712 - auc: 0.9316
# Epoch 27: val_accuracy did not improve from 0.87219
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3385 - accuracy: 0.8709 - auc: 0.9313 - val_loss: 0.3387 - val_accuracy: 0.8722 - val_auc: 0.9243
# Epoch 28/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.3301 - accuracy: 0.8740 - auc: 0.9332
# Epoch 28: val_accuracy did not improve from 0.87219
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3294 - accuracy: 0.8750 - auc: 0.9334 - val_loss: 0.3439 - val_accuracy: 0.8670 - val_auc: 0.9231
# Epoch 29/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3405 - accuracy: 0.8716 - auc: 0.9295
# Epoch 29: val_accuracy did not improve from 0.87219
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3404 - accuracy: 0.8715 - auc: 0.9293 - val_loss: 0.3362 - val_accuracy: 0.8722 - val_auc: 0.9261
# Epoch 30/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3378 - accuracy: 0.8762 - auc: 0.9301
# Epoch 30: val_accuracy improved from 0.87219 to 0.87565, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3380 - accuracy: 0.8753 - auc: 0.9301 - val_loss: 0.3372 - val_accuracy: 0.8756 - val_auc: 0.9263
# Epoch 31/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3331 - accuracy: 0.8738 - auc: 0.9334
# Epoch 31: val_accuracy did not improve from 0.87565
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3328 - accuracy: 0.8732 - auc: 0.9335 - val_loss: 0.3383 - val_accuracy: 0.8756 - val_auc: 0.9275
# Epoch 32/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8659 - auc: 0.9302
# Epoch 32: val_accuracy improved from 0.87565 to 0.87910, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3403 - accuracy: 0.8653 - auc: 0.9301 - val_loss: 0.3431 - val_accuracy: 0.8791 - val_auc: 0.9239
# Epoch 33/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3260 - accuracy: 0.8801 - auc: 0.9361
# Epoch 33: val_accuracy did not improve from 0.87910
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3281 - accuracy: 0.8796 - auc: 0.9353 - val_loss: 0.3340 - val_accuracy: 0.8791 - val_auc: 0.9318
# Epoch 34/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.3326 - accuracy: 0.8740 - auc: 0.9333
# Epoch 34: val_accuracy did not improve from 0.87910
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3330 - accuracy: 0.8736 - auc: 0.9331 - val_loss: 0.3613 - val_accuracy: 0.8722 - val_auc: 0.9223
# Epoch 35/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3272 - accuracy: 0.8822 - auc: 0.9344
# Epoch 35: val_accuracy improved from 0.87910 to 0.88428, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3279 - accuracy: 0.8817 - auc: 0.9343 - val_loss: 0.3335 - val_accuracy: 0.8843 - val_auc: 0.9264
# Epoch 36/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.3268 - accuracy: 0.8773 - auc: 0.9344
# Epoch 36: val_accuracy did not improve from 0.88428
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3281 - accuracy: 0.8769 - auc: 0.9341 - val_loss: 0.3395 - val_accuracy: 0.8774 - val_auc: 0.9248
# Epoch 37/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3272 - accuracy: 0.8774 - auc: 0.9335
# Epoch 37: val_accuracy did not improve from 0.88428
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3242 - accuracy: 0.8782 - auc: 0.9348 - val_loss: 0.3451 - val_accuracy: 0.8722 - val_auc: 0.9243
# Epoch 38/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.3251 - accuracy: 0.8798 - auc: 0.9354
# Epoch 38: val_accuracy did not improve from 0.88428
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3259 - accuracy: 0.8788 - auc: 0.9350 - val_loss: 0.3262 - val_accuracy: 0.8843 - val_auc: 0.9321
# Epoch 39/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.3212 - accuracy: 0.8827 - auc: 0.9372
# Epoch 39: val_accuracy did not improve from 0.88428
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3214 - accuracy: 0.8830 - auc: 0.9371 - val_loss: 0.3271 - val_accuracy: 0.8808 - val_auc: 0.9275
# Epoch 40/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3314 - accuracy: 0.8794 - auc: 0.9321
# Epoch 40: val_accuracy improved from 0.88428 to 0.88774, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3303 - accuracy: 0.8794 - auc: 0.9325 - val_loss: 0.3359 - val_accuracy: 0.8877 - val_auc: 0.9291
# Epoch 41/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3255 - accuracy: 0.8781 - auc: 0.9352
# Epoch 41: val_accuracy did not improve from 0.88774
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3274 - accuracy: 0.8778 - auc: 0.9347 - val_loss: 0.3275 - val_accuracy: 0.8808 - val_auc: 0.9313
# Epoch 42/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3166 - accuracy: 0.8820 - auc: 0.9380
# Epoch 42: val_accuracy did not improve from 0.88774
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3169 - accuracy: 0.8821 - auc: 0.9379 - val_loss: 0.3265 - val_accuracy: 0.8826 - val_auc: 0.9300
# Epoch 43/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3107 - accuracy: 0.8823 - auc: 0.9404
# Epoch 43: val_accuracy did not improve from 0.88774
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3103 - accuracy: 0.8830 - auc: 0.9403 - val_loss: 0.3203 - val_accuracy: 0.8860 - val_auc: 0.9348
# Epoch 44/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3202 - accuracy: 0.8844 - auc: 0.9382
# Epoch 44: val_accuracy did not improve from 0.88774
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3196 - accuracy: 0.8840 - auc: 0.9385 - val_loss: 0.3171 - val_accuracy: 0.8860 - val_auc: 0.9373
# Epoch 45/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.3146 - accuracy: 0.8866 - auc: 0.9388
# Epoch 45: val_accuracy did not improve from 0.88774
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3173 - accuracy: 0.8855 - auc: 0.9379 - val_loss: 0.3316 - val_accuracy: 0.8877 - val_auc: 0.9286
# Epoch 46/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.3141 - accuracy: 0.8848 - auc: 0.9395
# Epoch 46: val_accuracy did not improve from 0.88774
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3125 - accuracy: 0.8855 - auc: 0.9401 - val_loss: 0.3212 - val_accuracy: 0.8860 - val_auc: 0.9322
# Epoch 47/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.3154 - accuracy: 0.8837 - auc: 0.9381
# Epoch 47: val_accuracy improved from 0.88774 to 0.88946, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3160 - accuracy: 0.8842 - auc: 0.9381 - val_loss: 0.3191 - val_accuracy: 0.8895 - val_auc: 0.9349
# Epoch 48/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3141 - accuracy: 0.8857 - auc: 0.9394
# Epoch 48: val_accuracy did not improve from 0.88946
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3126 - accuracy: 0.8867 - auc: 0.9397 - val_loss: 0.3228 - val_accuracy: 0.8843 - val_auc: 0.9325
# Epoch 49/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.3115 - accuracy: 0.8820 - auc: 0.9401
# Epoch 49: val_accuracy improved from 0.88946 to 0.89119, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3129 - accuracy: 0.8811 - auc: 0.9394 - val_loss: 0.3250 - val_accuracy: 0.8912 - val_auc: 0.9333
# Epoch 50/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3095 - accuracy: 0.8847 - auc: 0.9407
# Epoch 50: val_accuracy did not improve from 0.89119
# 163/163 [==============================] - 1s 6ms/step - loss: 0.3093 - accuracy: 0.8849 - auc: 0.9406 - val_loss: 0.3190 - val_accuracy: 0.8860 - val_auc: 0.9367
# Epoch 51/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3056 - accuracy: 0.8879 - auc: 0.9429
# Epoch 51: val_accuracy did not improve from 0.89119
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3060 - accuracy: 0.8871 - auc: 0.9424 - val_loss: 0.3284 - val_accuracy: 0.8705 - val_auc: 0.9313
# Epoch 52/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3087 - accuracy: 0.8863 - auc: 0.9414
# Epoch 52: val_accuracy did not improve from 0.89119
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3081 - accuracy: 0.8863 - auc: 0.9415 - val_loss: 0.3341 - val_accuracy: 0.8860 - val_auc: 0.9305
# Epoch 53/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3066 - accuracy: 0.8855 - auc: 0.9406
# Epoch 53: val_accuracy improved from 0.89119 to 0.89292, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3059 - accuracy: 0.8849 - auc: 0.9409 - val_loss: 0.3162 - val_accuracy: 0.8929 - val_auc: 0.9350
# Epoch 54/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8880 - auc: 0.9394
# Epoch 54: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3099 - accuracy: 0.8880 - auc: 0.9394 - val_loss: 0.3204 - val_accuracy: 0.8877 - val_auc: 0.9347
# Epoch 55/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3013 - accuracy: 0.8886 - auc: 0.9429
# Epoch 55: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3009 - accuracy: 0.8890 - auc: 0.9431 - val_loss: 0.3394 - val_accuracy: 0.8877 - val_auc: 0.9281
# Epoch 56/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2982 - accuracy: 0.8926 - auc: 0.9446
# Epoch 56: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3020 - accuracy: 0.8907 - auc: 0.9434 - val_loss: 0.3083 - val_accuracy: 0.8877 - val_auc: 0.9417
# Epoch 57/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.3102 - accuracy: 0.8866 - auc: 0.9403
# Epoch 57: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3084 - accuracy: 0.8872 - auc: 0.9410 - val_loss: 0.3283 - val_accuracy: 0.8877 - val_auc: 0.9296
# Epoch 58/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2997 - accuracy: 0.8899 - auc: 0.9438
# Epoch 58: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3002 - accuracy: 0.8896 - auc: 0.9435 - val_loss: 0.3325 - val_accuracy: 0.8929 - val_auc: 0.9296
# Epoch 59/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3038 - accuracy: 0.8883 - auc: 0.9407
# Epoch 59: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3043 - accuracy: 0.8884 - auc: 0.9406 - val_loss: 0.3199 - val_accuracy: 0.8895 - val_auc: 0.9370
# Epoch 60/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2990 - accuracy: 0.8888 - auc: 0.9455
# Epoch 60: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2975 - accuracy: 0.8896 - auc: 0.9458 - val_loss: 0.3187 - val_accuracy: 0.8843 - val_auc: 0.9362
# Epoch 61/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.3084 - accuracy: 0.8894 - auc: 0.9403
# Epoch 61: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3088 - accuracy: 0.8890 - auc: 0.9401 - val_loss: 0.3237 - val_accuracy: 0.8912 - val_auc: 0.9321
# Epoch 62/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2935 - accuracy: 0.8924 - auc: 0.9452
# Epoch 62: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2943 - accuracy: 0.8922 - auc: 0.9452 - val_loss: 0.3144 - val_accuracy: 0.8895 - val_auc: 0.9378
# Epoch 63/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2977 - accuracy: 0.8871 - auc: 0.9443
# Epoch 63: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2976 - accuracy: 0.8872 - auc: 0.9442 - val_loss: 0.3087 - val_accuracy: 0.8877 - val_auc: 0.9385
# Epoch 64/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.3003 - accuracy: 0.8912 - auc: 0.9448
# Epoch 64: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 6ms/step - loss: 0.2989 - accuracy: 0.8920 - auc: 0.9453 - val_loss: 0.3122 - val_accuracy: 0.8860 - val_auc: 0.9364
# Epoch 65/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2944 - accuracy: 0.8895 - auc: 0.9462
# Epoch 65: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2949 - accuracy: 0.8886 - auc: 0.9458 - val_loss: 0.3165 - val_accuracy: 0.8912 - val_auc: 0.9327
# Epoch 66/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2912 - accuracy: 0.8892 - auc: 0.9467
# Epoch 66: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 9ms/step - loss: 0.2910 - accuracy: 0.8892 - auc: 0.9465 - val_loss: 0.3222 - val_accuracy: 0.8912 - val_auc: 0.9315
# Epoch 67/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.3014 - accuracy: 0.8893 - auc: 0.9429
# Epoch 67: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.3008 - accuracy: 0.8884 - auc: 0.9434 - val_loss: 0.3562 - val_accuracy: 0.8877 - val_auc: 0.9267
# Epoch 68/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2979 - accuracy: 0.8890 - auc: 0.9437
# Epoch 68: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2971 - accuracy: 0.8892 - auc: 0.9438 - val_loss: 0.3094 - val_accuracy: 0.8895 - val_auc: 0.9416
# Epoch 69/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2939 - accuracy: 0.8898 - auc: 0.9469
# Epoch 69: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2931 - accuracy: 0.8897 - auc: 0.9470 - val_loss: 0.3077 - val_accuracy: 0.8895 - val_auc: 0.9366
# Epoch 70/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2971 - accuracy: 0.8915 - auc: 0.9451
# Epoch 70: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2974 - accuracy: 0.8905 - auc: 0.9450 - val_loss: 0.3179 - val_accuracy: 0.8895 - val_auc: 0.9341
# Epoch 71/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.8926 - auc: 0.9458
# Epoch 71: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2938 - accuracy: 0.8926 - auc: 0.9458 - val_loss: 0.3291 - val_accuracy: 0.8912 - val_auc: 0.9300
# Epoch 72/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2874 - accuracy: 0.8933 - auc: 0.9480
# Epoch 72: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2908 - accuracy: 0.8917 - auc: 0.9467 - val_loss: 0.3097 - val_accuracy: 0.8843 - val_auc: 0.9415
# Epoch 73/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2964 - accuracy: 0.8913 - auc: 0.9448
# Epoch 73: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2978 - accuracy: 0.8909 - auc: 0.9441 - val_loss: 0.3253 - val_accuracy: 0.8929 - val_auc: 0.9320
# Epoch 74/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2892 - accuracy: 0.8952 - auc: 0.9471
# Epoch 74: val_accuracy did not improve from 0.89292
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2888 - accuracy: 0.8955 - auc: 0.9470 - val_loss: 0.3547 - val_accuracy: 0.8860 - val_auc: 0.9295
# Epoch 75/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2922 - accuracy: 0.8932 - auc: 0.9461
# Epoch 75: val_accuracy improved from 0.89292 to 0.89637, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2948 - accuracy: 0.8926 - auc: 0.9454 - val_loss: 0.3133 - val_accuracy: 0.8964 - val_auc: 0.9366
# Epoch 76/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2901 - accuracy: 0.8918 - auc: 0.9463
# Epoch 76: val_accuracy did not improve from 0.89637
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2892 - accuracy: 0.8913 - auc: 0.9467 - val_loss: 0.3100 - val_accuracy: 0.8877 - val_auc: 0.9363
# Epoch 77/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2825 - accuracy: 0.8956 - auc: 0.9493
# Epoch 77: val_accuracy did not improve from 0.89637
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2846 - accuracy: 0.8949 - auc: 0.9483 - val_loss: 0.3247 - val_accuracy: 0.8946 - val_auc: 0.9326
# Epoch 78/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2893 - accuracy: 0.8924 - auc: 0.9472
# Epoch 78: val_accuracy did not improve from 0.89637
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2917 - accuracy: 0.8920 - auc: 0.9468 - val_loss: 0.3071 - val_accuracy: 0.8946 - val_auc: 0.9399
# Epoch 79/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8957 - auc: 0.9504
# Epoch 79: val_accuracy improved from 0.89637 to 0.89810, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2817 - accuracy: 0.8957 - auc: 0.9504 - val_loss: 0.3084 - val_accuracy: 0.8981 - val_auc: 0.9380
# Epoch 80/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2877 - accuracy: 0.8929 - auc: 0.9474
# Epoch 80: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2880 - accuracy: 0.8919 - auc: 0.9474 - val_loss: 0.3149 - val_accuracy: 0.8929 - val_auc: 0.9360
# Epoch 81/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2877 - accuracy: 0.8972 - auc: 0.9472
# Epoch 81: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2877 - accuracy: 0.8976 - auc: 0.9473 - val_loss: 0.3180 - val_accuracy: 0.8877 - val_auc: 0.9331
# Epoch 82/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2858 - accuracy: 0.8922 - auc: 0.9477
# Epoch 82: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2859 - accuracy: 0.8922 - auc: 0.9477 - val_loss: 0.3065 - val_accuracy: 0.8826 - val_auc: 0.9408
# Epoch 83/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2845 - accuracy: 0.8934 - auc: 0.9489
# Epoch 83: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2825 - accuracy: 0.8936 - auc: 0.9497 - val_loss: 0.3085 - val_accuracy: 0.8826 - val_auc: 0.9403
# Epoch 84/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2873 - accuracy: 0.8941 - auc: 0.9479
# Epoch 84: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2892 - accuracy: 0.8938 - auc: 0.9476 - val_loss: 0.3191 - val_accuracy: 0.8964 - val_auc: 0.9335
# Epoch 85/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.8986 - auc: 0.9483
# Epoch 85: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2848 - accuracy: 0.8986 - auc: 0.9483 - val_loss: 0.3011 - val_accuracy: 0.8964 - val_auc: 0.9426
# Epoch 86/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2909 - accuracy: 0.8967 - auc: 0.9463
# Epoch 86: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2909 - accuracy: 0.8970 - auc: 0.9464 - val_loss: 0.3028 - val_accuracy: 0.8860 - val_auc: 0.9393
# Epoch 87/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.2795 - accuracy: 0.8960 - auc: 0.9503
# Epoch 87: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2825 - accuracy: 0.8936 - auc: 0.9492 - val_loss: 0.3088 - val_accuracy: 0.8929 - val_auc: 0.9381
# Epoch 88/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2841 - accuracy: 0.8940 - auc: 0.9490
# Epoch 88: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2833 - accuracy: 0.8949 - auc: 0.9494 - val_loss: 0.3061 - val_accuracy: 0.8964 - val_auc: 0.9352
# Epoch 89/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2847 - accuracy: 0.8932 - auc: 0.9477
# Epoch 89: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2860 - accuracy: 0.8932 - auc: 0.9476 - val_loss: 0.3068 - val_accuracy: 0.8912 - val_auc: 0.9377
# Epoch 90/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2789 - accuracy: 0.8940 - auc: 0.9510
# Epoch 90: val_accuracy did not improve from 0.89810
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2796 - accuracy: 0.8940 - auc: 0.9507 - val_loss: 0.3183 - val_accuracy: 0.8774 - val_auc: 0.9376
# Epoch 91/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2843 - accuracy: 0.8930 - auc: 0.9493
# Epoch 91: val_accuracy improved from 0.89810 to 0.89983, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2846 - accuracy: 0.8928 - auc: 0.9490 - val_loss: 0.3185 - val_accuracy: 0.8998 - val_auc: 0.9344
# Epoch 92/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2797 - accuracy: 0.8915 - auc: 0.9505
# Epoch 92: val_accuracy did not improve from 0.89983
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2824 - accuracy: 0.8913 - auc: 0.9499 - val_loss: 0.3121 - val_accuracy: 0.8912 - val_auc: 0.9402
# Epoch 93/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.8956 - auc: 0.9498
# Epoch 93: val_accuracy did not improve from 0.89983
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2810 - accuracy: 0.8945 - auc: 0.9491 - val_loss: 0.3063 - val_accuracy: 0.8946 - val_auc: 0.9424
# Epoch 94/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2761 - accuracy: 0.8986 - auc: 0.9522
# Epoch 94: val_accuracy improved from 0.89983 to 0.90501, saving model to /content/infobox_xy_1200_norm_1.h5
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2744 - accuracy: 0.8988 - auc: 0.9528 - val_loss: 0.3052 - val_accuracy: 0.9050 - val_auc: 0.9389
# Epoch 95/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.2800 - accuracy: 0.9002 - auc: 0.9506
# Epoch 95: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2791 - accuracy: 0.9001 - auc: 0.9508 - val_loss: 0.3029 - val_accuracy: 0.8929 - val_auc: 0.9448
# Epoch 96/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2781 - accuracy: 0.8993 - auc: 0.9506
# Epoch 96: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2789 - accuracy: 0.8990 - auc: 0.9501 - val_loss: 0.3082 - val_accuracy: 0.8860 - val_auc: 0.9417
# Epoch 97/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2771 - accuracy: 0.8993 - auc: 0.9505
# Epoch 97: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2760 - accuracy: 0.8997 - auc: 0.9508 - val_loss: 0.3032 - val_accuracy: 0.9016 - val_auc: 0.9406
# Epoch 98/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8968 - auc: 0.9504
# Epoch 98: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2784 - accuracy: 0.8968 - auc: 0.9504 - val_loss: 0.3103 - val_accuracy: 0.8998 - val_auc: 0.9380
# Epoch 99/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2801 - accuracy: 0.8976 - auc: 0.9500
# Epoch 99: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2815 - accuracy: 0.8980 - auc: 0.9496 - val_loss: 0.3145 - val_accuracy: 0.8946 - val_auc: 0.9333
# Epoch 100/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2805 - accuracy: 0.8975 - auc: 0.9499
# Epoch 100: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2802 - accuracy: 0.8978 - auc: 0.9499 - val_loss: 0.3239 - val_accuracy: 0.8998 - val_auc: 0.9345
# Epoch 101/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.8962 - auc: 0.9495
# Epoch 101: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2780 - accuracy: 0.8974 - auc: 0.9498 - val_loss: 0.3195 - val_accuracy: 0.8964 - val_auc: 0.9360
# Epoch 102/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2765 - accuracy: 0.8968 - auc: 0.9519
# Epoch 102: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2789 - accuracy: 0.8957 - auc: 0.9513 - val_loss: 0.3107 - val_accuracy: 0.8998 - val_auc: 0.9373
# Epoch 103/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2868 - accuracy: 0.8965 - auc: 0.9491
# Epoch 103: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2862 - accuracy: 0.8968 - auc: 0.9492 - val_loss: 0.3026 - val_accuracy: 0.8964 - val_auc: 0.9416
# Epoch 104/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8990 - auc: 0.9504
# Epoch 104: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2799 - accuracy: 0.8990 - auc: 0.9504 - val_loss: 0.3099 - val_accuracy: 0.8981 - val_auc: 0.9373
# Epoch 105/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.8945 - auc: 0.9519
# Epoch 105: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2743 - accuracy: 0.8945 - auc: 0.9519 - val_loss: 0.2977 - val_accuracy: 0.8981 - val_auc: 0.9427
# Epoch 106/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2733 - accuracy: 0.8981 - auc: 0.9517
# Epoch 106: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2726 - accuracy: 0.8984 - auc: 0.9519 - val_loss: 0.3141 - val_accuracy: 0.8912 - val_auc: 0.9376
# Epoch 107/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2720 - accuracy: 0.8968 - auc: 0.9525
# Epoch 107: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2727 - accuracy: 0.8965 - auc: 0.9523 - val_loss: 0.3379 - val_accuracy: 0.8826 - val_auc: 0.9288
# Epoch 108/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8970 - auc: 0.9506
# Epoch 108: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2758 - accuracy: 0.8970 - auc: 0.9506 - val_loss: 0.2991 - val_accuracy: 0.8964 - val_auc: 0.9432
# Epoch 109/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2698 - accuracy: 0.8988 - auc: 0.9534
# Epoch 109: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2708 - accuracy: 0.8990 - auc: 0.9530 - val_loss: 0.2966 - val_accuracy: 0.8929 - val_auc: 0.9449
# Epoch 110/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2639 - accuracy: 0.9012 - auc: 0.9553
# Epoch 110: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 2s 9ms/step - loss: 0.2642 - accuracy: 0.9011 - auc: 0.9552 - val_loss: 0.3033 - val_accuracy: 0.8877 - val_auc: 0.9448
# Epoch 111/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2726 - accuracy: 0.9037 - auc: 0.9516
# Epoch 111: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 2s 9ms/step - loss: 0.2713 - accuracy: 0.9036 - auc: 0.9520 - val_loss: 0.3053 - val_accuracy: 0.8946 - val_auc: 0.9393
# Epoch 112/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2767 - accuracy: 0.8988 - auc: 0.9519
# Epoch 112: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 9ms/step - loss: 0.2779 - accuracy: 0.8986 - auc: 0.9516 - val_loss: 0.2956 - val_accuracy: 0.8981 - val_auc: 0.9438
# Epoch 113/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2697 - accuracy: 0.8994 - auc: 0.9540
# Epoch 113: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2688 - accuracy: 0.8995 - auc: 0.9542 - val_loss: 0.3064 - val_accuracy: 0.8929 - val_auc: 0.9379
# Epoch 114/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2735 - accuracy: 0.8975 - auc: 0.9521
# Epoch 114: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2740 - accuracy: 0.8968 - auc: 0.9520 - val_loss: 0.3020 - val_accuracy: 0.8877 - val_auc: 0.9441
# Epoch 115/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2742 - accuracy: 0.8983 - auc: 0.9524
# Epoch 115: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2739 - accuracy: 0.8982 - auc: 0.9525 - val_loss: 0.3076 - val_accuracy: 0.8826 - val_auc: 0.9424
# Epoch 116/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2666 - accuracy: 0.8968 - auc: 0.9539
# Epoch 116: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2658 - accuracy: 0.8974 - auc: 0.9540 - val_loss: 0.3104 - val_accuracy: 0.8964 - val_auc: 0.9398
# Epoch 117/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2672 - accuracy: 0.9021 - auc: 0.9542
# Epoch 117: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2681 - accuracy: 0.9017 - auc: 0.9539 - val_loss: 0.3364 - val_accuracy: 0.8895 - val_auc: 0.9329
# Epoch 118/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2662 - accuracy: 0.9003 - auc: 0.9543
# Epoch 118: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2698 - accuracy: 0.8990 - auc: 0.9529 - val_loss: 0.2966 - val_accuracy: 0.8964 - val_auc: 0.9426
# Epoch 119/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2678 - accuracy: 0.9007 - auc: 0.9543
# Epoch 119: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2656 - accuracy: 0.9024 - auc: 0.9551 - val_loss: 0.3180 - val_accuracy: 0.9016 - val_auc: 0.9338
# Epoch 120/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2627 - accuracy: 0.9030 - auc: 0.9539
# Epoch 120: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2644 - accuracy: 0.9026 - auc: 0.9534 - val_loss: 0.2995 - val_accuracy: 0.8964 - val_auc: 0.9408
# Epoch 121/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2667 - accuracy: 0.9007 - auc: 0.9552
# Epoch 121: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2664 - accuracy: 0.9007 - auc: 0.9553 - val_loss: 0.3083 - val_accuracy: 0.8981 - val_auc: 0.9371
# Epoch 122/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2620 - accuracy: 0.9045 - auc: 0.9556
# Epoch 122: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2621 - accuracy: 0.9045 - auc: 0.9556 - val_loss: 0.3031 - val_accuracy: 0.8929 - val_auc: 0.9458
# Epoch 123/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8999 - auc: 0.9534
# Epoch 123: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2701 - accuracy: 0.8999 - auc: 0.9534 - val_loss: 0.3036 - val_accuracy: 0.8929 - val_auc: 0.9414
# Epoch 124/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2700 - accuracy: 0.9025 - auc: 0.9535
# Epoch 124: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2706 - accuracy: 0.9034 - auc: 0.9535 - val_loss: 0.3014 - val_accuracy: 0.8912 - val_auc: 0.9422
# Epoch 125/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2706 - accuracy: 0.9034 - auc: 0.9537
# Epoch 125: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2696 - accuracy: 0.9038 - auc: 0.9539 - val_loss: 0.3496 - val_accuracy: 0.8860 - val_auc: 0.9281
# Epoch 126/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2692 - accuracy: 0.8997 - auc: 0.9536
# Epoch 126: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2696 - accuracy: 0.8993 - auc: 0.9535 - val_loss: 0.3079 - val_accuracy: 0.8946 - val_auc: 0.9394
# Epoch 127/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2629 - accuracy: 0.9034 - auc: 0.9552
# Epoch 127: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2642 - accuracy: 0.9024 - auc: 0.9548 - val_loss: 0.3089 - val_accuracy: 0.9033 - val_auc: 0.9395
# Epoch 128/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2629 - accuracy: 0.9015 - auc: 0.9549
# Epoch 128: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2617 - accuracy: 0.9026 - auc: 0.9552 - val_loss: 0.3164 - val_accuracy: 0.8964 - val_auc: 0.9347
# Epoch 129/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2659 - accuracy: 0.9024 - auc: 0.9544
# Epoch 129: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2671 - accuracy: 0.9018 - auc: 0.9540 - val_loss: 0.2982 - val_accuracy: 0.8877 - val_auc: 0.9457
# Epoch 130/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2657 - accuracy: 0.9006 - auc: 0.9545
# Epoch 130: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2677 - accuracy: 0.8997 - auc: 0.9539 - val_loss: 0.3157 - val_accuracy: 0.8912 - val_auc: 0.9389
# Epoch 131/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.8968 - auc: 0.9541
# Epoch 131: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2676 - accuracy: 0.8968 - auc: 0.9541 - val_loss: 0.3245 - val_accuracy: 0.8929 - val_auc: 0.9340
# Epoch 132/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2591 - accuracy: 0.9031 - auc: 0.9566
# Epoch 132: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2588 - accuracy: 0.9036 - auc: 0.9567 - val_loss: 0.3002 - val_accuracy: 0.8998 - val_auc: 0.9416
# Epoch 133/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.8993 - auc: 0.9546
# Epoch 133: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2644 - accuracy: 0.8993 - auc: 0.9546 - val_loss: 0.3086 - val_accuracy: 0.8946 - val_auc: 0.9381
# Epoch 134/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9030 - auc: 0.9542
# Epoch 134: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2628 - accuracy: 0.9030 - auc: 0.9542 - val_loss: 0.3122 - val_accuracy: 0.8929 - val_auc: 0.9380
# Epoch 135/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2670 - accuracy: 0.9001 - auc: 0.9550
# Epoch 135: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2671 - accuracy: 0.9001 - auc: 0.9550 - val_loss: 0.3093 - val_accuracy: 0.8929 - val_auc: 0.9382
# Epoch 136/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9024 - auc: 0.9560
# Epoch 136: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2611 - accuracy: 0.9024 - auc: 0.9560 - val_loss: 0.3026 - val_accuracy: 0.8998 - val_auc: 0.9405
# Epoch 137/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2679 - accuracy: 0.9021 - auc: 0.9549
# Epoch 137: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2683 - accuracy: 0.9030 - auc: 0.9550 - val_loss: 0.2976 - val_accuracy: 0.8929 - val_auc: 0.9452
# Epoch 138/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9041 - auc: 0.9560
# Epoch 138: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2623 - accuracy: 0.9041 - auc: 0.9560 - val_loss: 0.3072 - val_accuracy: 0.8877 - val_auc: 0.9417
# Epoch 139/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2624 - accuracy: 0.9010 - auc: 0.9548
# Epoch 139: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2618 - accuracy: 0.9011 - auc: 0.9551 - val_loss: 0.3011 - val_accuracy: 0.8912 - val_auc: 0.9430
# Epoch 140/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2649 - accuracy: 0.9028 - auc: 0.9536
# Epoch 140: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2651 - accuracy: 0.9024 - auc: 0.9535 - val_loss: 0.3034 - val_accuracy: 0.8981 - val_auc: 0.9407
# Epoch 141/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2653 - accuracy: 0.9026 - auc: 0.9552
# Epoch 141: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2646 - accuracy: 0.9024 - auc: 0.9554 - val_loss: 0.3001 - val_accuracy: 0.8964 - val_auc: 0.9437
# Epoch 142/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.2620 - accuracy: 0.9036 - auc: 0.9559
# Epoch 142: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2619 - accuracy: 0.9032 - auc: 0.9557 - val_loss: 0.3013 - val_accuracy: 0.9016 - val_auc: 0.9400
# Epoch 143/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9049 - auc: 0.9581
# ...
# Epoch 147/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2598 - accuracy: 0.9069 - auc: 0.9573
# Epoch 147: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2608 - accuracy: 0.9063 - auc: 0.9567 - val_loss: 0.2986 - val_accuracy: 0.8929 - val_auc: 0.9438
# Epoch 148/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2703 - accuracy: 0.9034 - auc: 0.9554
# Epoch 148: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2704 - accuracy: 0.9032 - auc: 0.9554 - val_loss: 0.2985 - val_accuracy: 0.8929 - val_auc: 0.9442
# Epoch 149/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2648 - accuracy: 0.9027 - auc: 0.9545
# Epoch 149: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2636 - accuracy: 0.9028 - auc: 0.9549 - val_loss: 0.3067 - val_accuracy: 0.8981 - val_auc: 0.9414
# Epoch 150/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2565 - accuracy: 0.9007 - auc: 0.9578
# Epoch 150: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2565 - accuracy: 0.9009 - auc: 0.9577 - val_loss: 0.3057 - val_accuracy: 0.8929 - val_auc: 0.9384
# Epoch 151/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2535 - accuracy: 0.9047 - auc: 0.9570
# Epoch 151: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2532 - accuracy: 0.9041 - auc: 0.9572 - val_loss: 0.2994 - val_accuracy: 0.8860 - val_auc: 0.9451
# Epoch 152/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2606 - accuracy: 0.9020 - auc: 0.9547
# Epoch 152: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2588 - accuracy: 0.9038 - auc: 0.9554 - val_loss: 0.3106 - val_accuracy: 0.8895 - val_auc: 0.9411
# Epoch 153/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.2528 - accuracy: 0.9058 - auc: 0.9579
# Epoch 153: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2520 - accuracy: 0.9055 - auc: 0.9583 - val_loss: 0.2964 - val_accuracy: 0.8877 - val_auc: 0.9458
# Epoch 154/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2564 - accuracy: 0.9064 - auc: 0.9573
# Epoch 154: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2583 - accuracy: 0.9059 - auc: 0.9568 - val_loss: 0.2993 - val_accuracy: 0.8791 - val_auc: 0.9462
# Epoch 155/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2569 - accuracy: 0.9041 - auc: 0.9577
# Epoch 155: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2575 - accuracy: 0.9038 - auc: 0.9576 - val_loss: 0.2997 - val_accuracy: 0.8981 - val_auc: 0.9444
# Epoch 156/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2517 - accuracy: 0.9070 - auc: 0.9579
# Epoch 156: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2526 - accuracy: 0.9072 - auc: 0.9577 - val_loss: 0.2969 - val_accuracy: 0.8946 - val_auc: 0.9450
# Epoch 157/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2567 - accuracy: 0.9053 - auc: 0.9582
# Epoch 157: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2570 - accuracy: 0.9053 - auc: 0.9581 - val_loss: 0.3202 - val_accuracy: 0.8981 - val_auc: 0.9381
# Epoch 158/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.9047 - auc: 0.9600
# Epoch 158: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2506 - accuracy: 0.9049 - auc: 0.9601 - val_loss: 0.2969 - val_accuracy: 0.8929 - val_auc: 0.9448
# Epoch 159/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2574 - accuracy: 0.9047 - auc: 0.9566
# Epoch 159: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2570 - accuracy: 0.9047 - auc: 0.9568 - val_loss: 0.2940 - val_accuracy: 0.8912 - val_auc: 0.9462
# Epoch 160/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2489 - accuracy: 0.9053 - auc: 0.9601
# Epoch 160: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2505 - accuracy: 0.9049 - auc: 0.9595 - val_loss: 0.3128 - val_accuracy: 0.8998 - val_auc: 0.9373
# Epoch 161/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2489 - accuracy: 0.9034 - auc: 0.9591
# Epoch 161: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2517 - accuracy: 0.9030 - auc: 0.9587 - val_loss: 0.3478 - val_accuracy: 0.8895 - val_auc: 0.9309
# Epoch 162/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2487 - accuracy: 0.9098 - auc: 0.9606
# Epoch 162: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2490 - accuracy: 0.9095 - auc: 0.9604 - val_loss: 0.2985 - val_accuracy: 0.8981 - val_auc: 0.9427
# Epoch 163/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2608 - accuracy: 0.9061 - auc: 0.9564
# Epoch 163: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2599 - accuracy: 0.9065 - auc: 0.9566 - val_loss: 0.3052 - val_accuracy: 0.8912 - val_auc: 0.9403
# Epoch 164/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2618 - accuracy: 0.9029 - auc: 0.9561
# Epoch 164: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2611 - accuracy: 0.9032 - auc: 0.9564 - val_loss: 0.2995 - val_accuracy: 0.8895 - val_auc: 0.9457
# Epoch 165/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2534 - accuracy: 0.9062 - auc: 0.9584
# Epoch 165: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2536 - accuracy: 0.9059 - auc: 0.9583 - val_loss: 0.3258 - val_accuracy: 0.8964 - val_auc: 0.9355
# Epoch 166/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2507 - accuracy: 0.9101 - auc: 0.9585
# Epoch 166: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2507 - accuracy: 0.9099 - auc: 0.9585 - val_loss: 0.2973 - val_accuracy: 0.8998 - val_auc: 0.9444
# Epoch 167/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2558 - accuracy: 0.9027 - auc: 0.9573
# Epoch 167: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2570 - accuracy: 0.9018 - auc: 0.9569 - val_loss: 0.2946 - val_accuracy: 0.8981 - val_auc: 0.9463
# Epoch 168/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2526 - accuracy: 0.9068 - auc: 0.9581
# Epoch 168: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2528 - accuracy: 0.9070 - auc: 0.9581 - val_loss: 0.3088 - val_accuracy: 0.8981 - val_auc: 0.9361
# Epoch 169/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2510 - accuracy: 0.9101 - auc: 0.9588
# Epoch 169: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2513 - accuracy: 0.9103 - auc: 0.9587 - val_loss: 0.3069 - val_accuracy: 0.8912 - val_auc: 0.9415
# Epoch 170/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2485 - accuracy: 0.9037 - auc: 0.9586
# Epoch 170: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2459 - accuracy: 0.9043 - auc: 0.9595 - val_loss: 0.2960 - val_accuracy: 0.8964 - val_auc: 0.9447
# Epoch 171/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2499 - accuracy: 0.9132 - auc: 0.9584
# Epoch 171: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2508 - accuracy: 0.9126 - auc: 0.9581 - val_loss: 0.3130 - val_accuracy: 0.8912 - val_auc: 0.9385
# Epoch 172/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2560 - accuracy: 0.9062 - auc: 0.9569
# Epoch 172: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2549 - accuracy: 0.9068 - auc: 0.9572 - val_loss: 0.3415 - val_accuracy: 0.8895 - val_auc: 0.9326
# Epoch 173/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2552 - accuracy: 0.9080 - auc: 0.9580
# Epoch 173: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2565 - accuracy: 0.9074 - auc: 0.9575 - val_loss: 0.3125 - val_accuracy: 0.8981 - val_auc: 0.9382
# Epoch 174/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2512 - accuracy: 0.9064 - auc: 0.9595
# Epoch 174: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2512 - accuracy: 0.9065 - auc: 0.9595 - val_loss: 0.3056 - val_accuracy: 0.8981 - val_auc: 0.9399
# Epoch 175/1000
# 155/163 [===========================>..] - ETA: 0s - loss: 0.2503 - accuracy: 0.9069 - auc: 0.9588
# Epoch 175: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2532 - accuracy: 0.9061 - auc: 0.9577 - val_loss: 0.3163 - val_accuracy: 0.8912 - val_auc: 0.9388
# Epoch 176/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2533 - accuracy: 0.9076 - auc: 0.9577
# Epoch 176: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2506 - accuracy: 0.9090 - auc: 0.9586 - val_loss: 0.3042 - val_accuracy: 0.8895 - val_auc: 0.9403
# Epoch 177/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2576 - accuracy: 0.9025 - auc: 0.9569
# Epoch 177: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2571 - accuracy: 0.9018 - auc: 0.9572 - val_loss: 0.3044 - val_accuracy: 0.8981 - val_auc: 0.9407
# Epoch 178/1000
# 161/163 [============================>.] - ETA: 0s - loss: 0.2513 - accuracy: 0.9064 - auc: 0.9590
# Epoch 178: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2501 - accuracy: 0.9070 - auc: 0.9594 - val_loss: 0.3013 - val_accuracy: 0.8860 - val_auc: 0.9455
# Epoch 179/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2438 - accuracy: 0.9100 - auc: 0.9609
# Epoch 179: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2453 - accuracy: 0.9088 - auc: 0.9606 - val_loss: 0.2984 - val_accuracy: 0.8843 - val_auc: 0.9461
# Epoch 180/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.9088 - auc: 0.9607
# Epoch 180: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2444 - accuracy: 0.9088 - auc: 0.9607 - val_loss: 0.2970 - val_accuracy: 0.8964 - val_auc: 0.9443
# Epoch 181/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2456 - accuracy: 0.9088 - auc: 0.9603
# Epoch 181: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2489 - accuracy: 0.9084 - auc: 0.9600 - val_loss: 0.3005 - val_accuracy: 0.8860 - val_auc: 0.9430
# Epoch 182/1000
# 158/163 [============================>.] - ETA: 0s - loss: 0.2541 - accuracy: 0.9074 - auc: 0.9586
# Epoch 182: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2540 - accuracy: 0.9076 - auc: 0.9584 - val_loss: 0.2993 - val_accuracy: 0.8877 - val_auc: 0.9452
# Epoch 183/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2521 - accuracy: 0.9041 - auc: 0.9583
# Epoch 183: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2521 - accuracy: 0.9043 - auc: 0.9585 - val_loss: 0.3010 - val_accuracy: 0.8877 - val_auc: 0.9467
# Epoch 184/1000
# 156/163 [===========================>..] - ETA: 0s - loss: 0.2499 - accuracy: 0.9060 - auc: 0.9585
# Epoch 184: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2487 - accuracy: 0.9068 - auc: 0.9590 - val_loss: 0.3032 - val_accuracy: 0.8912 - val_auc: 0.9422
# Epoch 185/1000
# 163/163 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9118 - auc: 0.9619
# Epoch 185: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2430 - accuracy: 0.9118 - auc: 0.9619 - val_loss: 0.3293 - val_accuracy: 0.8964 - val_auc: 0.9358
# Epoch 186/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2516 - accuracy: 0.9049 - auc: 0.9586
# Epoch 186: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2507 - accuracy: 0.9051 - auc: 0.9588 - val_loss: 0.3168 - val_accuracy: 0.8981 - val_auc: 0.9382
# Epoch 187/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2465 - accuracy: 0.9080 - auc: 0.9604
# Epoch 187: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2467 - accuracy: 0.9078 - auc: 0.9603 - val_loss: 0.3034 - val_accuracy: 0.8877 - val_auc: 0.9457
# Epoch 188/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.9066 - auc: 0.9595
# Epoch 188: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2508 - accuracy: 0.9066 - auc: 0.9593 - val_loss: 0.3004 - val_accuracy: 0.8981 - val_auc: 0.9445
# Epoch 189/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2468 - accuracy: 0.9092 - auc: 0.9592
# Epoch 189: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 8ms/step - loss: 0.2484 - accuracy: 0.9084 - auc: 0.9586 - val_loss: 0.2932 - val_accuracy: 0.8929 - val_auc: 0.9469
# Epoch 190/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2397 - accuracy: 0.9090 - auc: 0.9621
# Epoch 190: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2399 - accuracy: 0.9097 - auc: 0.9620 - val_loss: 0.2946 - val_accuracy: 0.8912 - val_auc: 0.9461
# Epoch 191/1000
# 160/163 [============================>.] - ETA: 0s - loss: 0.2425 - accuracy: 0.9076 - auc: 0.9605
# Epoch 191: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2421 - accuracy: 0.9076 - auc: 0.9607 - val_loss: 0.2990 - val_accuracy: 0.8895 - val_auc: 0.9443
# Epoch 192/1000
# 162/163 [============================>.] - ETA: 0s - loss: 0.2398 - accuracy: 0.9118 - auc: 0.9615
# Epoch 192: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2403 - accuracy: 0.9116 - auc: 0.9614 - val_loss: 0.3000 - val_accuracy: 0.8912 - val_auc: 0.9465
# Epoch 193/1000
# 159/163 [============================>.] - ETA: 0s - loss: 0.2463 - accuracy: 0.9102 - auc: 0.9594
# Epoch 193: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2488 - accuracy: 0.9090 - auc: 0.9586 - val_loss: 0.2975 - val_accuracy: 0.8929 - val_auc: 0.9477
# Epoch 194/1000
# 157/163 [===========================>..] - ETA: 0s - loss: 0.2470 - accuracy: 0.9086 - auc: 0.9597
# Epoch 194: val_accuracy did not improve from 0.90501
# 163/163 [==============================] - 1s 7ms/step - loss: 0.2477 - accuracy: 0.9076 - auc: 0.9596 - val_loss: 0.2943 - val_accuracy: 0.8860 - val_auc: 0.9481
# Epoch 194: early stopping

# %%
# Test
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from matplotlib import pyplot as plt
from tensorflow import keras
import seaborn as sns
import pandas as pd


model = keras.models.load_model(results_path + '/' + model_name + '.h5')
model.summary()
results = model.evaluate(X_test, y_test)

print('\nTest Loss, Test Accuracy, Test AUC:', results)

# Generate confusion matrix and compute metrics
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
conf_mat = confusion_matrix(y_test.argmax(axis=1), y_pred)
tn, fp, fn, tp = conf_mat.ravel()
precision = precision_score(y_test.argmax(axis=1), y_pred)
recall = recall_score(y_test.argmax(axis=1), y_pred)
f1_score = f1_score(y_test.argmax(axis=1), y_pred)

print('\nPrecision: ' + str(precision))
print('Recall: ' + str(recall))
print('F1-score: ' + str(f1_score))
print('\nTrue Negatives: ' + str(tn))
print('False Positives: ' + str(fp))
print('False Negatives: ' + str(fn))
print('True Positives: ' + str(tp) + '\n')

fig = plt.figure()
sns.heatmap(conf_mat, annot=True, fmt="d",cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion matrix')
fig.savefig(results_path + '/' + model_name + '_confusion_matrix.png')
plt.show()

data = {'a': [results[0], results[1], results[2], precision, recall, f1_score, tn, fp, fn, tp]}
df = pd.DataFrame(data=data, index=['Test Loss', 'Test Accuracy', 'Test AUC', 'Precision', 'Recall', 'F1-score', 'True Negatives', 'False Positives', 'False Negatives', 'True Positives'])
df.to_csv(results_path + '/' + model_name + '_results.csv', header=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1181, 110)         2310
#
#  max_pooling1d (MaxPooling1D  (None, 73, 110)          0
#  )
#
#  dropout (Dropout)           (None, 73, 110)           0
#
#  conv1d_1 (Conv1D)           (None, 64, 100)           110100
#
#  global_average_pooling1d (G  (None, 100)              0
#  lobalAveragePooling1D)
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 2)                 202
#
# =================================================================
# Total params: 112,612
# Trainable params: 112,612
# Non-trainable params: 0
# _________________________________________________________________
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3066 - accuracy: 0.8885 - auc: 0.9448
#
# Test Loss, Test Accuracy, Test AUC: [0.30657505989074707, 0.88852459192276, 0.9448105692863464]
#
# Precision: 0.9041095890410958
# Recall: 0.868421052631579
# F1-score: 0.8859060402684564
#
# True Negatives: 139
# False Positives: 14
# False Negatives: 20
# True Positives: 132

# %%
# Save test dataset
import csv
import os


if len(os.listdir(test_dataset_path + '/false')) == 0 and len(os.listdir(test_dataset_path + '/true')) == 0:
  for i in range(0,len(X_test)):
    if y_test[i][1] == 1:
      test_class = "true"
    else:
      test_class = "false"
    with open(test_dataset_path + '/' + test_class + '/' + test_class + '_' + str(i+1) + '.csv', 'w') as csvfile:
      writer = csv.writer(csvfile)
      writer.writerow([""])
      for j in range(0, len(X_test[0])):
        writer.writerow([str(X_test[i][j][0])])
      writer.writerow([""])
